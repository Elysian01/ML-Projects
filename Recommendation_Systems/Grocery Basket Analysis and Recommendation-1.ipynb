# %% [markdown]
# # Grocery Product Recommendation using Apriori Algorithm

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations, groupby
from collections import Counter

from apyori import apriori
from mlxtend import frequent_patterns 
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# #### [Dataset link from kaggle](https://www.kaggle.com/c/instacart-market-basket-analysis/data)

# %%
prior_order_df = pd.read_csv("./instacart-market-basket-analysis/order_products_prior.csv")
prior_order_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Over 32 million grocery orders from more than 200,000 Instacart users
# 50K unique items, 3.2M unique orders
prior_order_df.shape
# Out:
# (32434489, 4)

# %%
prior_order_df.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
products_df = pd.read_csv("./instacart-market-basket-analysis/products.csv")
products_df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
products_df.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
# Making required dataset
prior_order_df = prior_order_df.drop(columns = ["add_to_cart_order", "reordered"])
products_df = products_df.drop(columns = ["aisle_id","department_id"])

orders_df = prior_order_df.merge(products_df, on="product_id")
orders_df.head()
# Out:
#    order_id  product_id        product_name
# 0         2       33120  Organic Egg Whites
# 1        26       33120  Organic Egg Whites
# 2       120       33120  Organic Egg Whites
# 3       327       33120  Organic Egg Whites
# 4       390       33120  Organic Egg Whites

# %%
# Getting Only a subset to reduce computational cost
subset = orders_df[orders_df['order_id']<10000]

# %%
subset.shape
# Out:
# (94482, 3)

# %%
subset.head(10)
# Out:
#    order_id  product_id        product_name
# 0         2       33120  Organic Egg Whites
# 1        26       33120  Organic Egg Whites
# 2       120       33120  Organic Egg Whites
# 3       327       33120  Organic Egg Whites
# 4       390       33120  Organic Egg Whites
# 5       537       33120  Organic Egg Whites
# 6       582       33120  Organic Egg Whites
# 7       608       33120  Organic Egg Whites
# 8       623       33120  Organic Egg Whites
# 9       689       33120  Organic Egg Whites

# %%
subset[subset["order_id"] == 4]
# Out:
#         order_id  product_id  \
# 570685         4       46842
# 579585         4       26434
# 579690         4       39758
# 582039         4       27761
# 584216         4       10054
# 585445         4       21351
# 587798         4       22598
# 588556         4       34862
# 593016         4       40285
# 595238         4       17616
# 602619         4       25146
# 627537         4       32645
# 628577         4       41276
#
#                                              product_name
# 570685                            Plain Pre-Sliced Bagels
# 579585                            Honey/Lemon Cough Drops
# 579690         Chewy 25% Low Sugar Chocolate Chip Granola
# 582039                        Oats & Chocolate Chewy Bars
# 584216        Kellogg's Nutri-Grain Apple Cinnamon Cereal
# 585445  Nutri-Grain Soft Baked Strawberry Cereal Break...
# 587798             Kellogg's Nutri-Grain Blueberry Cereal
# 588556                               Tiny Twists Pretzels
# 593016                              Traditional Snack Mix
# 595238              Goldfish Cheddar Baked Snack Crackers
# 602619                              Original Orange Juice
# 627537                             Sugarfree Energy Drink
# 628577                                       Energy Drink

# %%
subset.drop(columns = ["product_id"], inplace=True)
subset.head()
# Out:
# D:\Setups\Anaconda\Setup\envs\tensor\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    order_id        product_name
# 0         2  Organic Egg Whites
# 1        26  Organic Egg Whites
# 2       120  Organic Egg Whites
# 3       327  Organic Egg Whites
# 4       390  Organic Egg Whites

# %%
subset["product_name"] = subset["product_name"].str.strip()
# Out:
# D:\Setups\Anaconda\Setup\envs\tensor\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
subset[subset["product_name"] == "Clementines"]
# Out:
#          order_id product_name
# 1221921         5  Clementines
# 1221922        61  Clementines
# 1221923       152  Clementines
# 1221924       303  Clementines
# 1221925       315  Clementines
# ...           ...          ...
# 1221998      9187  Clementines
# 1221999      9251  Clementines
# 1222000      9273  Clementines
# 1222001      9696  Clementines
# 1222002      9868  Clementines
#
# [82 rows x 2 columns]

# %%
subset[subset["order_id"] == 61]
# Out:
#          order_id                         product_name
# 1221922        61                          Clementines
# 3976390        61                 Organic Baby Carrots
# 4077283        61           Frozen Organic Blueberries
# 5716668        61         Sea Salt Brown Rice Crackers
# 7688048        61             Premium Grapefruit Large
# 7690230        61  Dairy Free Unsweetened Coconut Milk
# 7698306        61                  Original Almondmilk
# 7702860        61           with Crispy Almonds Cereal
# 7707190        61                 Organic Low Fat Milk
# 7715628        61                  Half And Half Cream
# 7721909        61                 Non Fat Greek Yogurt
# 7726057        61             0% Greek Strained Yogurt

# %%
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94482 entries, 0 to 30093879
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      94482 non-null  int64
#  1   product_name  94482 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ MB

# %%
trans = subset.groupby(['order_id'], as_index = False).agg({'product_name': ','.join})
trans.head()
# Out:
#    order_id                                       product_name
# 0         2  Organic Egg Whites,Michigan Organic Kale,Garli...
# 1         3  Total 2% with Strawberry Lowfat Greek Strained...
# 2         4  Plain Pre-Sliced Bagels,Honey/Lemon Cough Drop...
# 3         5  Bag of Organic Bananas,Just Crisp, Parmesan,Fr...
# 4         6  Cleanse,Dryer Sheets Geranium Scent,Clean Day ...

# %%
# trans[trans["order_id"] == 2]["product_name"]
trans.iloc[1000,1]
# Out:
# 'Lemonade,Limes,Red Hot Original Cayenne Pepper Sauce,Original No Pulp 100% Florida Orange Juice,Celery Sticks,The Original Worcestershire Sauce'

# %% [markdown]
# # Implementing Apriori algorithm using Apyori Package

# %%
trans_list = []
for i in range(trans.shape[0]):
    trans_list.append(trans["product_name"][i].strip().split(","))
    
trans_list
# Out:
# [['Organic Egg Whites',
#   'Michigan Organic Kale',
#   'Garlic Powder',
#   'Coconut Butter',
#   'Natural Sweetener',
#   'Carrots',
#   'Original Unflavored Gelatine Mix',
#   'All Natural No Stir Creamy Almond Butter',
#   'Classic Blend Cole Slaw'],
#  ['Total 2% with Strawberry Lowfat Greek Strained Yogurt',
#   'Unsweetened Almondmilk',
#   'Lemons',
#   'Organic Baby Spinach',
#   'Unsweetened Chocolate Almond Breeze Almond Milk',
#   'Organic Ginger Root',
#   'Air Chilled Organic Boneless Skinless Chicken Breasts',
#   'Organic Ezekiel 49 Bread Cinnamon Raisin'],
#  ['Plain Pre-Sliced Bagels',
#   'Honey/Lemon Cough Drops',
#   'Chewy 25% Low Sugar Chocolate Chip Granola',
#   'Oats & Chocolate Chewy Bars',
#   "Kellogg's Nutri-Grain Apple Cinnamon Cereal",
#   'Nutri-Grain Soft Baked Strawberry Cereal Breakfast Bars',
#   "Kellogg's Nutri-Grain Blueberry Cereal",
#   'Tiny Twists Pretzels',
#   'Traditional Snack Mix',
#   'Goldfish Cheddar Baked Snack Crackers',
#   'Original Orange Juice',
#   'Sugarfree Energy Drink',
#   'Energy Drink'],
#  ['Bag of Organic Bananas',
#   'Just Crisp',
#   ' Parmesan',
#   'Fresh Fruit Salad',
#   'Organic Raspberries',
#   '2% Reduced Fat Milk',
#   'Sensitive Toilet Paper',
#   'Natural Artesian Water',
#   ' Mini & Mobile',
#   'Matzos',
#   ' Thin',
#   ' Tea',
#   'Boneless Skinless Chicken Breast Fillets',
#   'Mini Original Babybel Cheese',
#   'Macaroni And Cheese',
#   'Clementines',
#   "Biscuits Orange Pim's",
#   'Dairy Milk Fruit & Nut Chocolate Bar',
#   'Artichokes',
#   'Apricot Preserves',
#   'One Ply Choose A Size Big Roll Paper Towel Rolls',
#   'Wafer',
#   ' Chocolate',
#   'French Lavender Hand Wash',
#   'American Slices Cheese',
#   'Everyday  Facial Tissues',
#   'Organic Hass Avocado',
#   'Spaghetti Pasta',
#   'Meyer Lemon',
#   'Bag of Organic Lemons',
#   'Original Black Box Tablewater Cracker'],
#  ['Cleanse',
#   'Dryer Sheets Geranium Scent',
#   'Clean Day Lavender Scent Room Freshener Spray'],
#  ['Orange Juice', 'Pineapple Chunks'],
#  ['Original Hawaiian Sweet Rolls'],
#  ['Organic Red Radish',
#   ' Bunch',
#   'Whole White Mushrooms',
#   'Baby Spinach',
#   'Low Fat Kefir Cultured Milk Smoothie Lowfat Probiotic Blueberry',
#   'Snak-Saks Crackers',
#   'Natural Applesauce Snack & Go Pouches',
#   'Green Beans',
#   'Extra Virgin Olive Oil',
#   'Distilled Water',
#   'French Baguettes',
#   ' Take & Bake',
#   ' Twin Pack',
#   'Organic Bread with 21 Whole Grains',
#   '100% Apple Juice Original',
#   'Vanilla Almond Breeze Almond Milk',
#   'Natural Sharp Cheddar Sliced Cheese',
#   'Fruit & Nutty Almonds Raisins Cranberries Pecans Granola'],
#  ['Green Beans',
#   'Banana',
#   'Baby Portabella Mushrooms',
#   'Organic Cilantro',
#   'Organic Avocado',
#   'Yellow Onions',
#   'Parsley',
#   ' Italian (Flat)',
#   ' New England Grown',
#   'Organic Strawberries',
#   'Stage 2 Green Bean Pear Greek Yogurt Baby Food',
#   'Spinach Peas & Pear Stage 2 Baby Food',
#   'Organic Black Beans',
#   'Organic Half & Half',
#   'Boneless Beef Sirloin Steak',
#   'Organic Butterhead (Boston',
#   ' Butter',
#   ' Bibb) Lettuce',
#   'Organic Sunchoke'],
#  ['Extra Virgin Olive Oil',
#   'Teriyaki & Pineapple Chicken Meatballs',
#   'Mango Pineapple Salsa',
#   'Traditional Refried Beans',
#   'Tortilla Strips Restaurant Style'],
#  ['French Vanilla Coffee Creamer',
#   '2% Milk',
#   'Cherubs Heavenly Salad Tomatoes',
#   'Extra Creamy Dairy Whipped Topping',
#   '100% Cranberry Juice',
#   'Ruby Red Grapefruit Juice',
#   '100% Juice No Added Sugar Orange Tangerine',
#   '100% Juice No Sugar Added Apple',
#   'Cheddar Cheese Condensed Soup',
#   'All Natural Boneless Skinless Chicken Breasts',
#   'Sweet & Salty Snack Mix',
#   'Game Day Barbecue Trail Mix',
#   'Chocolate Caramel Cashew Trail Mix',
#   'Combination Pizza Rolls',
#   'Sunrise Grilled Steak and Eggs Canine Cuisine Wet Dog Food'],
#  ['Light',
#   'Chunky Salsa Medium',
#   'Handmade Vodka From Austin',
#   ' Texas',
#   'Soda',
#   'Salsa Con Queso Medium Dip',
#   'G Series Lime Cucumber Sports Drink',
#   'Lemon Lime Thirst Quencher',
#   'Lemonade',
#   'Sparkling Natural Mineral Water',
#   'Diet Tonic Water',
#   'Philadelphia Original Cream Cheese',
#   'Hampshire 100% Natural Sour Cream',
#   'Original Potato Chips'],
#  ['Hair Bender Whole Bean Coffee',
#   'Organic Whole Milk',
#   'Organic Mini Homestyle Waffles',
#   'Naturals Chicken Nuggets',
#   'Unprocessed American Singles Colby-Style Cheese',
#   'Organic Mesa Sunrise Cereal',
#   'Total Greek Strained Yogurt',
#   'Corn Meal Pizza Crust',
#   'Sriracha Chili Sauce',
#   'Organic Broccoli Florets',
#   'Honeycrisp Apple'],
#  ['Spring Water',
#   'Organic Extra Virgin Olive Oil',
#   'Pinto Beans No Salt Added',
#   'Honeysuckle Hand Soap',
#   'Olive Oil & Aloe Vera Hand Soap'],
#  ['Original Popcorn', 'Water', 'Sea Salt Made With Organic Grain Rice Chips'],
#  ['Organic Raspberries',
#   'Organic Avocado',
#   '100% Recycled Paper Towels',
#   'Red Vine Tomato',
#   'Apricots',
#   'Watermelon Chunks',
#   'Organic Fat Free Milk',
#   'Sparkling Water Grapefruit',
#   'Organic Bosc Pear',
#   'Organic Stage 4 Spinach Mango & Pear Baby Food',
#   'Ataulfo Mango',
#   'Globe Eggplant',
#   'Organic Unsalted Butter',
#   'Sesame Oil',
#   ' Pure',
#   'Frozen Broccoli Florets',
#   'Organic Maple & Onion Baked Beans',
#   'Pear Kiwi & Kale Baby Food',
#   'Organic Fiber & Protein Pear Blueberry & Spinach Baby Food',
#   'Cilantro Pesto',
#   'Raspberry Preserves',
#   'Balsamic Reduction Traditional Balsamic',
#   'Pitted Prunes',
#   'Sweet Corn On The Cob',
#   'Organic Hazelnut Spread',
#   'Organic Baby Kale',
#   'Low Sodium Bacon',
#   'Asparagus',
#   'Basil',
#   ' Asiago & Pine Nut Pesto Ravioli'],
#  ['Unsweetened Almondmilk',
#   'Organic Baby Carrots',
#   'Organic Whole White Mushrooms'],
#  ['Banana',
#   'Nilla Wafers',
#   'Mini Chocolate Chip Waffles',
#   'Sweet Red Grape Tomatoes',
#   "Danimals Swingin' Strawberry Banana Smoothie",
#   'Fruit Punch Sports Drink',
#   'Red Delicious Apple',
#   'Oven Baked Original Potato Chips'],
#  ['Yuba Tofu Skin',
#   'Organic Firm Tofu',
#   'Frozen Organic Blueberries',
#   'Dairy-Free Cheddar Style Wedges',
#   'Cold Brew Coffee'],
#  ['2% Reduced Fat Milk',
#   'Banana',
#   'Asparagus',
#   'Butter Top White Bread',
#   'Iceberg Lettuce',
#   'Broccoli Florets',
#   'Large Grade AA Eggs',
#   'Provolone Slices',
#   'Vine Ripe Tomatoes',
#   'Boneless And Skinless Chicken Breast',
#   'Deli Fresh Honey Smoked Turkey Breast',
#   ' 98% Fat Free',
#   ' Gluten Free',
#   'Presliced Everything Bagels',
#   'Cream Cheese',
#   'Sandwich Bags'],
#  ['Organic Avocado',
#   'Organic Baby Spinach Salad',
#   'Red Leaf Lettuce',
#   'Potato Yukon Gold Organic',
#   'White Corn',
#   'Gluten-Free Supergrain Pasta Organic Corn & Quinoa Blend Penne',
#   'Gluten and Dairy Free Sonoma Veggie Burger',
#   'Organic Three Grain Tempeh',
#   'Lime',
#   'Organic Red Onion',
#   'Dairy-Free Chive Cream Cheese',
#   'Healthy Organic Vinaigrette',
#   '34% Cacao Milk Chocolate Bar',
#   'Fluoride-Free Antiplaque & Whitening Spearmint Toothpaste'],
#  ['Strawberry Lemonade Frozen Pops',
#   'Mint Chocolate Cookie Ice Cream',
#   'Half Baked® Ice Cream'],
#  ['Original Popcorn',
#   'Boomchickapop Sweet & Salty Kettle Corn',
#   'Steamfresh Lightly Sauced Broccoli With Cheese Sauce',
#   'Delights Turkey Sausage Egg Whites & Cheese English Muffin',
#   'Ultra Thin Sliced Provolone Cheese',
#   'Cheese Shredded Mozzarella Reduced Fat 2%',
#   'All Whites 100% Egg Whites',
#   'Smok Cured Turkey Bacon',
#   'Shredded Hash Browns',
#   'Simply 9 White Meat Chicken & Whole Barley Recipe Dog Food',
#   'Craveables Four Cheese Pizza',
#   'Macaroni and Cheese',
#   'Natural Muenster Cheese',
#   'Baby Cut Carrots'],
#  ['Organic Egg Whites',
#   'Organic Baby Spinach',
#   'Banana',
#   'Organic Avocado',
#   'Organic Unsweetened Almond Milk',
#   'Red Grapefruit',
#   'Boneless Skinless Chicken Breasts',
#   'Berry Medley'],
#  ['Michigan Organic Kale',
#   'Carrots',
#   'Bag of Organic Bananas',
#   'Organic Avocado',
#   'Low Fat Vanilla Yogurt',
#   'Lemon Hummus',
#   'Roasted Red Pepper Hummus',
#   'Dark Chocolate Chips',
#   'Organic Low Sodium Vegetable Broth',
#   'Organic Sour Cream',
#   'Green Bell Pepper',
#   'Organic No Salt Added Diced Tomatoes',
#   'No Salt Added Black Beans',
#   'Firm Tofu',
#   'Organic Eggplant',
#   'Organic Marinara Pasta Sauce',
#   'Organic Bunch Beets',
#   'Feta Cheese Crumbles',
#   'Pasta Joy Ready Organic Brown Rice Pasta Penne',
#   '3 lb Clementines',
#   'Organic Whole Strawberries',
#   'Organic Mango Chunks',
#   'Teriyaki Veggie Burgers',
#   'Organic Tomato Cluster',
#   'Coconut Sugar Pure & Unrefined',
#   'Almond Meal/Flour',
#   'Parchment Paper'],
#  ['Air Chilled Organic Boneless Skinless Chicken Breasts',
#   'Organic Hass Avocado',
#   'Cream Cheese',
#   'Salted Butter',
#   "Organic D'Anjou Pears",
#   'Cultured Low Fat Buttermilk',
#   'Large Lemon',
#   'Organic Strawberry Fruit Spread',
#   'Large Greenhouse Tomato',
#   'Original Semisoft Cheese',
#   'Whole Organic Omega 3 Milk',
#   'Organic Heavy Whipping Cream',
#   '1% Lowfat Milk',
#   'Organic Whole Milk Strawberry Beet Berry Yogurt Pouch',
#   'Organic Black Plum',
#   'Organic Red Delicious Apple'],
#  ['Bag of Organic Bananas',
#   'Raspberries',
#   'Smartwater',
#   'Baby Cucumbers',
#   'Sinfully Sweet Campari Tomatoes'],
#  ['Synergy Organic Kombucha Gingerberry',
#   'Mango Chunks',
#   'Organic Unsweetened Soy Milk Beverage'],
#  ['Organic Baby Spinach',
#   'Organic Cilantro',
#   'Earl Grey Tea',
#   'Organic Yellow Onion',
#   'Seedless Red Grapes',
#   'Heirloom Tomato',
#   'Organic Whole Grain Sprouted Quinoa',
#   'Roasted & Salted Almonds',
#   'Uncured',
#   ' No Sugar',
#   ' Hickory Smoked Bacon',
#   'Organic Vidalia Onion'],
#  ['Bag of Organic Bananas',
#   'Organic Bread with 21 Whole Grains',
#   'Organic Broccoli Florets',
#   'Seedless Red Grapes',
#   'Organic Lactose Free 1% Lowfat Milk',
#   'Lactose Free Grade A Low Fat Vanilla Yogurt',
#   'Organic Mixed Vegetables',
#   'Cucumber Kirby',
#   'Clementines',
#   ' Bag'],
#  ['Gluten Free Mushroom Risotto Bowl',
#   'Cold-Brew Black Coffee',
#   'Kale',
#   ' Apple',
#   ' Ginger',
#   ' Romaine',
#   ' Spinach',
#   ' Cucumber',
#   ' Celery',
#   ' Parsley',
#   ' Lemon Cold Pressed Juice Beverage',
#   'Organic Olive Oil  Spray',
#   'Baby Swiss Slices Cheese',
#   'Gourmet Mochi Ice Cream Vanilla Bonbons',
#   'Eucalyptus & Peppermint Body Wash',
#   'Original Recipe Rice Pudding',
#   'Gluten Free Chocolate Chip Cookies'],
#  ['Bunny-Luv Organic Carrots',
#   'Cranberry Almond Chicken Salad',
#   'Coconut Water',
#   'Sea Salt Brown Rice Crackers',
#   'Madeleines'],
#  ['Organic Tortilla Chips', 'Ice Peppermint Gum', 'Wint-O-Green'],
#  ['Organic Baby Spinach',
#   'Yellow Onions',
#   'Organic Garnet Sweet Potato (Yam)',
#   'Organic Fuji Apple',
#   'Sliced Genoa Salami'],
#  ['Sparkling Natural Mineral Water',
#   'Organic 1% Low Fat Milk',
#   'Macaroni & Cheese',
#   'Chocolate Milk 1% Milkfat'],
#  ['Uncured Genoa Salami', 'All Natural Seasoned Waffle Cut Fries'],
#  ['Bag of Organic Bananas',
#   'Unsweetened Vanilla Almond Breeze',
#   'Pure Irish Butter'],
#  ['Mozzarella Light Low Moisture Part Skim String Cheese',
#   'White Cheddar Semisoft Cheese',
#   '13 Gallon Kitchen Drawstring Trash Bags',
#   'Classic Variety Pack Donuts',
#   'Original Denture Adhesive Cream',
#   'Lowfat 2% Milkfat Cottage Cheese',
#   'Black Seedless Grapes'],
#  ['Presliced Everything Bagels',
#   'Sausage Biscuit',
#   'Diet Mountain Dew Soda',
#   'Cereal',
#   'Breaded Chicken Breast Tenders',
#   'Honey Roasted Turkey',
#   'Clover Honey Bear',
#   'French Onion Dip',
#   'Chicken Pot Pie',
#   'Eggo Nutri-Grain Blueberry Waffles'],
#  ['Organic Yams'],
#  ['Pain Reliever/Fever Reducer (NSAID)',
#   ' Ibuprofen 200mg',
#   'Flour Tortillas',
#   'Light Sour Cream',
#   'Wheat Thins Reduced Fat Crackers',
#   'Simply 100® Blueberry Blended Non-Fat Greek Yogurt',
#   'Simply 100 Strawberry Blended Non-Fat Greek Yogurt',
#   '90 Calories Low Fat Chocolate Chunk Granola Bars',
#   'Reduced Fat Sliced Provolone Cheese',
#   'Deli Select Ultra Thin Honey Ham',
#   'Reduced Sugar Mixed Fruit Fruit Snacks',
#   'Reduced Fat Original Potato Crisps',
#   'Ultra Soft Bathroom Tissue',
#   ' Double Rolls',
#   "Cafe Steamers General Tso's Spicy Chicken",
#   'Chicken Marsala',
#   '100% Whole Wheat Bread',
#   "Berries 'n Cherries Fruit Snacks",
#   'Plates',
#   ' 10-1/16 Inch',
#   'Casual Napkins',
#   'Original',
#   "Thick 'N Creamy Macaroni & Cheese"],
#  ['Raspberries',
#   'Strawberries',
#   'Organic Blueberries',
#   'Beef Franks',
#   'Golden Pineapple'],
#  ['Organic Chicken Bone Broth',
#   'Yo Baby Organic Whole Milk Banana Mango Yogurt',
#   'YoKids Squeezers Organic Low-Fat Yogurt',
#   ' Strawberry',
#   'Low Sodium Beef Broth',
#   'Organic Unrefined Toasted Sesame Oil',
#   'Gluten-Free Chicken Nuggets',
#   'Original Barbeque Sauce',
#   'Milk',
#   ' Vitamin D'],
#  ['Organic Blueberry',
#   'Bananas',
#   'Single Origin 3',
#   'Original Pure Creamy Almond Milk'],
#  ['Pure Granulated Cane Sugar',
#   'Mango Yoghurt',
#   'Peach Yoghurt',
#   'All Natural Gluten Free Probiotic Pineapple Yoghurt',
#   'Organic Fresh Basil',
#   'Shredded Parmesan',
#   'French Vanilla Ice Cream'],
#  ['Organic Extra Virgin Olive Oil',
#   'Artesano Style Bread',
#   'Milk Whole',
#   'Baby Dynamic Duo Potatoes',
#   'Living Potted Rosemary',
#   'Yellow Straightneck Squash',
#   'Acorn Squash',
#   'Cookie Sheets',
#   'Italian Sparkling Pomegranate And Orange Soda'],
#  ['Banana',
#   'Cucumber Kirby',
#   'Apple Cider Vinegar',
#   'Gala Apples',
#   'Cinnamon Raisin Granola'],
#  ['Organic Hass Avocado',
#   'Banana',
#   'Large Lemon',
#   'Organic Blueberries',
#   'Yo Baby Organic Whole Milk Banana Mango Yogurt',
#   'Organic Gala Apples',
#   'Sprouted Multi-Grain Bread',
#   'Organic Original Tofu Veggie Burger',
#   'Sweet Baguette',
#   'Organic Grape Tomatoes',
#   'Organic Lemon',
#   'Organic Traditional Flour Tortillas',
#   'Organic Raw Sharp Cheddar Cheese',
#   'Original Veggie Straws',
#   'Burrata'],
#  ['Banana',
#   'Philadelphia Original Cream Cheese',
#   'Nilla Wafers',
#   'Instant French Vanilla Pudding & Pie Filling',
#   'Mixed Berries Wildly Nutritious Signature Blends',
#   'Original Whipped Topping',
#   'Sliced Peaches'],
#  ['Bag of Organic Bananas',
#   'Organic Raspberries',
#   'Organic Butterhead (Boston',
#   ' Butter',
#   ' Bibb) Lettuce',
#   'Organic Red Onion',
#   'Organic Tomato Cluster',
#   'Organic Lemon',
#   'Unsalted Butter',
#   'Semi-Sweet Chocolate Premium Baking Chips',
#   'Total 2% Lowfat Plain Greek Yogurt',
#   'Roasted Mushroom Pizza',
#   'Italian Sausage Pizza',
#   'Organic Cucumber',
#   'Spaghetti',
#   'Large Alfresco Eggs',
#   'Organic Spinach Bunch',
#   'Blood Oranges',
#   'Sea Salt & Vinegar Potato Chips',
#   'Organic 21 Grain Thin Sliced Bread',
#   'Organic Large Green Asparagus',
#   'Organic Braeburn Apple',
#   '100% Pure Rosemary',
#   'Root + Hair Deep Repair Conditioning Hair Mask'],
#  ['Organic Baby Spinach',
#   'Organic Hass Avocado',
#   'Orange Juice',
#   'Shredded Parmesan',
#   'Large Alfresco Eggs',
#   'Organic Tomato Paste',
#   'Organic Garlic',
#   'Blueberries',
#   'Buttermilk Biscuits',
#   'Coconut Almond Creamer Blend'],
#  ['Organic Baby Spinach',
#   'Organic Hass Avocado',
#   'Organic Strawberries',
#   'Ultra-Purified Water',
#   'Organic Bartlett Pear',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Authentic French Brioche'],
#  ['Bag of Organic Bananas',
#   'Organic Baby Carrots',
#   "Organic D'Anjou Pears",
#   'Marinara Sauce',
#   'Organic Original Hommus',
#   'Organic Blackberries'],
#  ['Prepared Meals Simmered Chicken Medley Wet Dog Food',
#   'Chopped Blends With Beef',
#   ' Carrots',
#   ' Peas & Barley Dog Food',
#   'Prepared Meals Beef Stew Wet Dog Food'],
#  ['Carrots',
#   'Bag of Organic Bananas',
#   'Organic Raspberries',
#   'Organic Yellow Onion',
#   'Milk',
#   ' Vitamin D',
#   'Organic Gala Apples',
#   'Organic Australian Style Vanilla Lowfat Yogurt',
#   'Tomato Sauce',
#   'Real Cola',
#   'Organic Honeydew',
#   'Organic Green Seedless Grapes',
#   'Muffins',
#   ' Mini',
#   ' Flax',
#   ' Chocolate Brownie',
#   'Organic Whole Wheat Bread',
#   'Organic Shredded Mild Cheddar',
#   'Skim Milk',
#   'Organic Diced Tomatoes',
#   'Organic Roasted Turkey Breast',
#   'Organic Spring Mix Salad'],
#  ['Clementines',
#   'Organic Baby Carrots',
#   'Frozen Organic Blueberries',
#   'Sea Salt Brown Rice Crackers',
#   'Premium Grapefruit Large',
#   'Dairy Free Unsweetened Coconut Milk',
#   'Original Almondmilk',
#   'with Crispy Almonds Cereal',
#   'Organic Low Fat Milk',
#   'Half And Half Cream',
#   'Non Fat Greek Yogurt',
#   '0% Greek Strained Yogurt'],
#  ['Organic Avocado',
#   'No Salt Added Black Beans',
#   'Tilapia Filet',
#   'Organic Lactose Free Whole Milk',
#   'XL Emerald White Seedless Grapes',
#   'Limes',
#   'Jalapeno Peppers'],
#  ['Garlic Powder',
#   'Wild Blend Rice',
#   'Reduced-fat Soft Cream Cheese',
#   'Whole Grain Oatmeal Bread',
#   'Steamfresh Selects Frozen Broccoli',
#   ' Cauliflower & Carrots',
#   'Steamfresh Premium Selects Frozen Whole Green Beans',
#   'Boneless Skinless Chicken Breast',
#   'Turkey',
#   'Red Bell Pepper',
#   'Red Potatoes'],
#  ['Caramel Vanilla Cream Light Roast K-Cup Packs Arabica Coffee',
#   'Half And Half Ultra Pasteurized',
#   'Purified Water',
#   'Ultra Soft & Strong® Toilet Paper Double Rolls',
#   'Smoothies',
#   ' Strawberries Wild'],
#  ['Organic 1% Lowfat Milk', 'Organic 2% Reduced Fat Milk', 'Soy Sauce'],
#  ['Organic Lightly Salted Sea Salt Thin & Crispy Restaurant Style Tortilla Chips',
#   'All Natural Marinara Pasta Sauce',
#   'Organic Reduced Fat Milk',
#   'Roman Raspberry Sorbetto',
#   'Soft Baked Chocolate Chip Cookies Gluten Free',
#   'Honey Lemon Ginseng Green Tea Bags'],
#  ['Bag of Organic Bananas',
#   'Plain Greek Yogurt',
#   'Maple Glazed Honey Ham',
#   'Organic Grade A Large Brown Eggs',
#   'Cherry Garcia Ice Cream',
#   'Prosciutto',
#   'Thick & Crispy Tortilla Chips',
#   'High Pulp Orange Juice'],
#  ['Soda',
#   'Non Fat Greek Yogurt',
#   'Variety Diet Tea',
#   'Seltzer Water',
#   'Gourmet Tomato Medley',
#   'Granny Smith Apples',
#   'Ginger Dressing',
#   'Migraine Caplets',
#   'Blackberries'],
#  ['Spinach Peas & Pear Stage 2 Baby Food',
#   'Organic Whole Milk',
#   'Baby Food Stage 2 Blueberry Pear & Purple Carrot',
#   'Baby Food Pouch - Kale',
#   ' Sweet Corn & Quinoa',
#   'Baby Food Pouch - Butternut Squash',
#   ' Carrot & Chickpea',
#   'Baby Food Pouch - Roasted Carrot Spinach & Beans',
#   'Chocolate Peanut Butter Cup Gelato',
#   'Carrot Raisin Flax Muffins',
#   'Hass Avocados',
#   'Organic Romaine Leaf',
#   'Stage 2 Spinach',
#   ' Apple & Kale'],
#  ['100% Whole Wheat Hot Dog Buns',
#   'Organic Quinoa & Brown Rice With Garlic',
#   'Organic Greek Whole Milk Blended Vanilla Bean Yogurt',
#   'Boneless Chicken Breast'],
#  ['Organic Hass Avocado',
#   'Organic Cilantro',
#   'Sparkling Water Grapefruit',
#   'Organic Lemon',
#   'Tilapia Filet',
#   'Limes',
#   'Toasted Coconut Chips Original Recipe',
#   'Organic Crushed Fire Roasted Tomatoes',
#   'Fresh Ginger Root',
#   'Clay Instant Luminous Facial Mask'],
#  ['Banana',
#   'Organic Fuji Apple',
#   'Pulp Free Orange Juice',
#   'Toasted Coconut Almondmilk Blend',
#   'Forelle Pears',
#   'Original Traditional Dijon Mustard',
#   'Baby Boomer Fresh Creamer Potatoes',
#   'Vegan Buttery Sticks',
#   'Squeeze Real Mayonnaise',
#   'Organic  Unsalted  Butter',
#   'Organic Homogenized Whole Milk'],
#  ['Organic Baby Spinach',
#   'Bunny-Luv Organic Carrots',
#   'Olive Bread',
#   'Organic Simply Naked Pita Chips'],
#  ['Organic Ginger Root',
#   'Organic Chicken Bone Broth',
#   'Organic Low Sodium Chicken Cooking Stock',
#   'Original Soy Creamer',
#   'Liquid Egg Whites',
#   'Americone Dream® Ice Cream',
#   'Rosemary Ham',
#   'Organic Mayonnaise',
#   'Organic Sunday Bacon',
#   'Organic Beefsteak Tomato',
#   'Organic Roma Tomato'],
#  ['Roasted Red Pepper Hummus',
#   'Sinfully Sweet Campari Tomatoes',
#   'Organic Blueberries',
#   'Sea Salt & Vinegar Potato Chips',
#   'Hass Avocados',
#   'Organic Plain Greek Whole Milk Yogurt',
#   'Mint Chip',
#   'Organic Short Brown Sprouted Rice',
#   'Organic Baby Arugula',
#   'Gum Ginger',
#   'Four Cheese Thin Crust Pizza',
#   'Dark Chocolate Covered Banana',
#   'Grated Parmesan Cheese',
#   'Tomato Basil Bisque Soup',
#   'Imported Capote Capers',
#   'Roasted Garlic Loaf'],
#  ['Cinnamon Sugar Cookie Chips',
#   'Seedless Watermelon',
#   'Fresh Sugar Snap Peas',
#   'Grape Tomatoes',
#   'Mini Sweet Peppers'],
#  ['Red Vine Tomato',
#   'Large Lemon',
#   'Organic Yellow Onion',
#   'Organic Cucumber',
#   'Lentil Chips',
#   ' Aged White Cheddar',
#   'Organic Gluten Free Maple Buckwheat Flakes',
#   'Organic Vanilla Soymilk',
#   'Sparkling Mineral Water',
#   'Red Peppers',
#   'Yellow Bell Pepper',
#   'Apple Honeycrisp Organic',
#   'Orange Bell Pepper',
#   'Beyond Beef Beefy Crumble',
#   'California Sourdough Bread',
#   'Hummus',
#   ' Hope',
#   ' Original Recipe',
#   'Sea Salt Pita Chips',
#   'Seven Grain Crispy Tenders',
#   'Organic Tomato Basil Pasta Sauce',
#   'Marinara Pasta Sauce',
#   'Organic Extra Large Grade AA Brown Eggs',
#   'Veggie Burger',
#   ' Quarter Pound'],
#  ['Strawberries',
#   'Fat Free Skim Milk',
#   'Fresh Mozzarella All-Natural Sliced Cheese',
#   'Roasted Pine Nut Hummus',
#   'Whole Grain Cheddar Baked Snack Crackers'],
#  ['Whole Milk',
#   'Bag of Oranges',
#   'Coffee Mate French Vanilla Creamer Packets',
#   'English Breakfast Tea Bags',
#   'Cozy Chamomile Herbal Tea',
#   'Earl Grey Tea Bags',
#   'Sponge Scrubber - 3 CT',
#   'Original Magic Eraser'],
#  ['Banana',
#   'Organic Whole Milk',
#   'Organic Blackberries',
#   'Yellow Bell Pepper',
#   'Organic Yokids Lemonade/Blueberry Variety Pack Yogurt Squeezers Tubes',
#   'Kid Z Bar Organic Honey Graham Energy Snack',
#   'Sour Cream'],
#  ['Unsweetened Almondmilk',
#   'Organic Hass Avocado',
#   'Organic Strawberries',
#   'Organic Baby Spinach Salad',
#   'Sliced Baby Bella Mushrooms',
#   'Organic Acorn Squash',
#   'Canary Melon',
#   'Organic English Cucumber',
#   'Organic Kiwi',
#   'Fancy Whole Artichoke Hearts',
#   'Brussels Sprouts'],
#  ['Strawberries',
#   'Organic Gala Apples',
#   'Reduced Fat Milk 2%',
#   'Premium Traditional Homestyle Cream Style Corn',
#   'Organic Whole Kernel Sweet Corn No Salt Added',
#   'Mild Diced Green Chiles',
#   'Organic Beef Uncured Hot Dogs',
#   'Organic Chocolate Flavored Syrup'],
#  ['Bag of Organic Bananas',
#   'Yellow Onions',
#   'Raspberries',
#   'Toasted Coconut Chips Original Recipe',
#   'Sunrise Crunchy Cinnamon Cereal',
#   'Organic Vanilla Almond Milk',
#   'Large Pineapple Chunks',
#   'Light & Lean Sweet & Sour Asian Noodle Pasta',
#   'Light & Lean Black Bean and Cheese Enchilada',
#   'Light and Lean 3 Cheese Penne Marinara',
#   'Crackers Cheddar Bunnies Snack Packs',
#   'Cheese Ravioli',
#   'Juice Beverage',
#   ' Cold Pressed',
#   ' Kale Apple Ginger Romaine Spinach Cucumber Celery Parsley Lemon',
#   'Original BBQ Sauce'],
#  ['Organic Milk',
#   'Ancient Grain Blueberry Hemp Granola',
#   'Pure Organic Pineapple Juice',
#   'Bunched Cilantro',
#   'Organic Mint',
#   'Organic Vitality Snack Chia Squeeze Blackberry Bliss',
#   'Mango Coconut Chia Squeeze',
#   'Tomatoes',
#   ' Crushed',
#   ' Organic',
#   'Chai Green Tea Bags 16 Count'],
#  ['Strawberries',
#   'Green Seedless Grapes',
#   'Red Globe Grapes',
#   'Mini Marshmallows',
#   'Miniatures',
#   "L'elegance Toothpicks",
#   'Medium Cookie Sheet',
#   'Medium Roast Original Blend Ground Coffee',
#   'Ultra Soft Facial Tissues'],
#  ['Toilet Bowl Cleaner with Bleach Rain Clean',
#   'Murphy Oil Soap Squirt & Mop Wood Floor Cleaner',
#   'gel hand wash sea minerals',
#   'ForceFlex Medium Quick-Tie Garbage',
#   'Dha Omega 3 Vitamin D Milk',
#   'Disinfecting Multi-Surface Cleaner Lemongrass Citrus Scent',
#   'Natural Free & Clear Dishwasher Detergent Packs',
#   'Organic Whole Grain Wheat English Muffins'],
#  ['Strawberries',
#   'Blackberry Cucumber Sparkling Water',
#   'Cantaloupe Grapefruit Sparkling Water',
#   'Lite Salt',
#   'Chopped Green Chiles',
#   'Turkey Store Lean Ground Turkey',
#   'Complete™ ActionPacs™ Fresh Scent Dishwasher Detergent',
#   'Clear Tone Pink Rosa Antiperspirant Deodorant',
#   'Leafy Green Romaine Lettuce',
#   'Aged White Cheddar Baked Rice And Corn Puffs',
#   'Original Fresh Stack Crackers',
#   'Salt & Vinegar Potato Chips',
#   'Ion4 Mountain Berry Blast',
#   'Mountain berry Blast Sports Drink',
#   'Honey Mustard Dressing Topping & Spread'],
#  ['Banana',
#   'Organic Avocado',
#   'Organic Strawberries',
#   'Iceberg Lettuce',
#   'Low Fat Vanilla Yogurt',
#   'Large Lemon',
#   'Original Semisoft Cheese',
#   'Mango Chunks',
#   'Cucumber Kirby',
#   'Organic Grade A Large Brown Eggs',
#   'Organic Baby Arugula',
#   'Half And Half',
#   'Organic Strawberry Smoothie',
#   'Total 2% All Natural Greek Strained Yogurt with Honey',
#   'Plus Cranberry Almond + Antioxidants with Macadamia Nuts Bar',
#   'Organic Peeled Whole Baby Carrots',
#   'Garlic Hummus',
#   'Penne Rigate #41 Pasta',
#   'Smoked Turkey Breast Slices',
#   'Apple Cinnamon GoGo Squeez',
#   'Atlantic Salmon Fillets',
#   'Baby Seedless Cucumbers',
#   'Asparation/Broccolini/Baby Broccoli'],
#  ['Carrots',
#   'Artichokes',
#   'Ataulfo Mango',
#   'Organic Lemon',
#   'Sweet & Salty Kettlecorn'],
#  ['Organic Baby Carrots',
#   'Organic Diced Tomatoes',
#   'Crescent Rolls',
#   'Organic Tomato Sauce',
#   'Organic Whole Peeled Tomatoes'],
#  ['Organic Celery',
#   'Organic Shredded Unsweetened Coconut',
#   'Lightly Breaded Fish Sticks',
#   'Quinoa & Leeks with Chicken + Tarragon Organic Baby Food',
#   'Smoked Maple Ham',
#   'Organic Avocados'],
#  ['Organic Baby Spinach',
#   'Banana',
#   'Organic Strawberries',
#   'Organic Half & Half',
#   'Organic Tortilla Chips',
#   'Buttermilk Biscuits',
#   'Organic Blackberries',
#   'Organic Beefsteak Tomato',
#   'Organic Kiwi',
#   'Organic Vanilla Almond Milk',
#   'Goodness Grapeness Organic Juice Drink',
#   'Wild Berry Smoothie',
#   'Organic Jasmine Rice',
#   'Organic Toaster Pastries Frosted Lotta Chocolotta - 6 CT',
#   'Sea Salt Potato Chips',
#   'Organic Beef Hot Dogs',
#   'Coconut Aminos Teriyaki Sauce',
#   'Organic Yellow Mustard',
#   'Gluten Free Hamburger Buns',
#   'Chopped Onions',
#   'Summertime Blues Multigrain Tortilla Chips',
#   'Medium Salsa Organica',
#   'Organic Hass Avocado Bag',
#   'Canned Aranciata Orange',
#   'Organic Turkey Bacon'],
#  ['Bag of Organic Bananas',
#   '2% Reduced Fat Milk',
#   'Gala Apples',
#   'Chewy Granola Bars Variety Pack',
#   'Taco Seasoning Mix Original',
#   'Sweetened Corn & Oat Cereal',
#   '100% Pineapple Juice',
#   'Crunchy Taco Shells',
#   'French Vanilla Creamer',
#   'Pure & Natural Sour Cream',
#   'Ultra Apple Blossom Antibacterial Dish Liquid',
#   '37% Less Sodium Soy Sauce',
#   'Roma Tomato',
#   'Delifresh Combos The Honey Smoked Turkey Breast Honey Ham'],
#  ['Large Alfresco Eggs',
#   'Lime Sparkling Water',
#   'Walnut Halves & Pieces',
#   'Frozen Organic Wild Blueberries'],
#  ['Organic Avocado',
#   'Organic Strawberries',
#   'Cucumber Kirby',
#   'Organic Kiwi',
#   'Purity Farms Ghee Clarified Butter',
#   'Wild Sockeye Salmon',
#   'Boneless & Skinless Wild Alaskan Sockeye Salmon',
#   'Organic Whole String Cheese',
#   'Organic Free Range Large Grade A Brown Eggs',
#   'Plain Goat Milk Yogurt',
#   'Hickory Smoked Ham',
#   'Organic Muenster Cheese',
#   'Natural Chicken & Maple Breakfast Sausage Patty',
#   'Chicken & Maple Breakfast Sausage'],
#  ['Half Baked® Ice Cream',
#   'Classic Variety Pack Donuts',
#   'YoKids Squeezers Organic Low-Fat Yogurt',
#   ' Strawberry',
#   'Organic Yokids Lemonade/Blueberry Variety Pack Yogurt Squeezers Tubes',
#   'Goodness Grapeness Organic Juice Drink',
#   'Multi-Grain Sea Salt Crackers',
#   'Chocolate Chip Cookie Dough Ice Cream',
#   'Organic YoKids Smoothie Strawberry Banana Lowfat Yogurt',
#   'Bunny Pasta with Yummy Cheese Macaroni & Cheese',
#   'French Roast Ground Coffee',
#   '3 Minute Miracle Moist Deep Conditioning Treatment',
#   'Chicken Apple Sausage Egg White Breakfast Burrito',
#   'Icelandic Style Skyr Blueberry Non-fat Yogurt',
#   'Uncured Slow Cooked Ham',
#   'Deep Moisture Body Wash',
#   'Peanut Butter Whole Grain Clusters',
#   'Epsom Salt Soaking Solution Soothe & Sleep',
#   'Purely Pampering Body Wash Shea Butter and Warm Vanilla',
#   'Classic Scent Liquid Dish Soap',
#   'Condensed Cream of Mushroom Soup',
#   'Oil-Free Acne Wash',
#   'No Sugar Added Variety Fruit Bars',
#   'Bagel Thins Everything',
#   'Hazelnut Spread With Skim Milk & Cocoa',
#   'White Distilled Vinegar',
#   'Shampoo',
#   ' Body Wash',
#   ' Bubble Bath Coconut+Lemon',
#   'Moroccan Argan Oil Renewing Shampoo'],
#  ['YoKids Blueberry & Strawberry/Vanilla Yogurt',
#   'Apple Juice',
#   'Hearty Style 100% Whole Grain Whole Wheat Bread',
#   'Uncured Beef Hot Dogs',
#   'Fully Cooked Maple Sausages 10 Count',
#   'Cream Cheese Cream Cheese Spread',
#   'Tamari Gluten Free Soy Sauce Reduced Sodium'],
#  ['Soda', 'Spring Water'],
#  ['Large Lemon',
#   'Toasted Coconut Almondmilk Blend',
#   'Organic Baby Arugula',
#   'Vidalia Onion and Cilantro Dressing Marinade',
#   'Mini Cucumbers',
#   'Sea Salt Popcorn',
#   'Lemon Italian Sparkling Mineral Water',
#   'Organic Fresh Carrot Chips',
#   'Tortilla Chips with Salt',
#   'Organic Matcha Tea Bags',
#   'Flat Fillets of Anchovies',
#   'Organic Whole Wheat Fusilli'],
#  ['Organic Raspberries',
#   'Roma Tomato',
#   'Natural Black Cherry Gels Gelatin Free Snacks',
#   'Organic Romaine',
#   'Fresh Cauliflower',
#   'Organic Avocados Hass Variety',
#   'Thick & Chunky Salsa',
#   'Kale Greens',
#   'Rice Thins Brown Rice Snack Crackers',
#   'Brown Rice Pasta Spirals'],
#  ['French Roast Ground Coffee',
#   'House Blend Deep Roast Ground Coffee',
#   "Major Dickason's Blend Ground Coffee Dark Roast",
#   "Major Dickason's Blend Whole Bean Coffee"],
#  ['Watermelon Chunks',
#   'Organic Blackberries',
#   'Oven Roasted Turkey',
#   'Total 0% Raspberry Yogurt'],
#  ['Bag of Organic Bananas',
#   'Seedless Red Grapes',
#   'Organic Fuji Apple',
#   'YoKids Squeezers Organic Low-Fat Yogurt',
#   ' Strawberry',
#   'Whole Milk',
#   'Apple Cinnamon GoGo Squeez',
#   'Chocolate Chip Cookie Dough Ice Cream',
#   'Natural Artisan Water',
#   'Real Aged Cheddar Macaroni & Cheese',
#   'Organic AppleApple',
#   'Whole Milk With Vitamin D',
#   'Cage Free Large White Eggs'],
#  ['Natural Muenster Cheese',
#   'Green Bell Pepper',
#   'Jalapeno Peppers',
#   'Baby Boomer Fresh Creamer Potatoes',
#   'Red Peppers',
#   'Whole Milk',
#   'Extra Large Grade A Eggs',
#   'Original Slices Pepperoni',
#   'Original Breakfast Sausage Links',
#   'Hot Italian Sausage',
#   'Chocolate Chip Cookie Dough',
#   'Sesame Topped Hamburger Buns',
#   'Unsweetened Original Almond Breeze Almond Milk',
#   'Chocolate Peanut Butter Ice Cream',
#   'Macaroni & Cheese Dinner Original Flavor',
#   'Rice Sides Chicken Flavor',
#   'Penne Pasta',
#   'Grands Southern Homestyle Biscuit',
#   'Pasta Sides Butter Flavor Fettuccini',
#   'Rice Sides Chicken Flavor Broccoli',
#   'Organic Seasoned Yukon Select Potatoes Hashed Browns',
#   'Honey Mustard and Onion Pretzels Pieces',
#   'Pasta Sides Chicken Flavor',
#   'Signature Recipes Vodka Sauce Pasta Sauce',
#   'Pasta Sauce',
#   ' Original',
#   ' Traditional',
#   'Mild Diced Tomatoes & Green Chilies',
#   'Charcoal Briquets Easy Light Bag',
#   'Sweet Onions',
#   'Shoestrings French Fried Potatoes',
#   'Spicy Brown Mustard',
#   'Baby Moisture Wash',
#   'Set Me Up Beautiful Bold Hold Hairspray',
#   ' Max',
#   'Herbal Body Envy',
#   'Color Treated Herbal Essences Color Me Happy Hair Conditioner for Color-Treated Hair 23.7 Fl Oz Female Hair Care'],
#  ['Organic Cucumber',
#   'Organic Lactose Free Whole Milk',
#   'Organic Red Chard Greens',
#   'Whole Wheat Bunnies Baked Snack Crackers',
#   'Apple & Cherry Fruit Bar',
#   'Creamy Peanut Butter',
#   '1 Apple + 1 Pear Fruit Bar'],
#  ['Watermelon Chunks',
#   'Organic Fat Free Milk',
#   'Lemongrass Citrus Scent Disinfecting Wipes',
#   'All Natural Powder Cleanser',
#   'Lavender Multi-Surface Everyday Cleaner',
#   'Lavender Scent Multi-Surface Cleaner Concentrate',
#   'Tomato Ketchup',
#   'Thin Sliced American Cheese',
#   'Liquid Hand Soap',
#   ' Refill',
#   ' Lavender Scent'],
#  ['Original Orange Juice',
#   'Organic Unsalted Butter',
#   'Ultra Soft Facial Tissues',
#   'Dressing & Marinade',
#   ' Toasted Sesame',
#   'Paper Towels',
#   'Kitchen Cleaner + Bleach',
#   ' Fresh Scent',
#   'Frappuccino Vanilla Chilled Coffee Drink Coffee Substitutes',
#   'Frozen Organic Strawberries',
#   'Mexican Blend Cheese',
#   'Electrolyte Enhanced Water',
#   'Traditional Hearty Chicken and Rotini Soup',
#   'Rich & Hearty Chicken & Homestyle Noodles Soup',
#   'Organic Low Sodium Chunky Tomato Bisque Soup',
#   'Organic Blend Me Mixed Vegetables',
#   'Organic Light in Sodium Lentil Vegetable Soup',
#   'Fresh Donuts',
#   'Clean Care Bath Tissue Rolls',
#   'Maxi pads Overnight With Flexi-Wings',
#   'Harvest Cheddar Multigrain Chips',
#   'SleepGels Nighttime Sleep Aid',
#   'Oven Roasted Turkey Breast'],
#  ['Organic Red Radish',
#   ' Bunch',
#   'Banana',
#   'Red Vine Tomato',
#   'Organic Unsweetened Almond Milk',
#   'Organic Lemon',
#   'Jalapeno Peppers',
#   'Beef Top Round Steak',
#   'Cotija',
#   'Organic Iceberg Lettuce',
#   'B 12 Liquid B Complex'],
#  ['Air Chilled Organic Boneless Skinless Chicken Breasts',
#   'Cucumber Kirby',
#   'Strawberries',
#   'Roasted Turkey',
#   'Organic Chai Tea Latte Concentrate'],
#  ['Organic Baby Spinach',
#   'Baby Swiss Slices Cheese',
#   'Organic Grade A Large Brown Eggs',
#   'Organic Vanilla Almond Milk',
#   'Bread Crumbs',
#   'Organic Nectarine',
#   'Russet Potato'],
#  ['Italian Sausage Pizza',
#   'Total 0% with Honey Nonfat Greek Strained Yogurt',
#   'Sea Salted Reduced Fat Potato Chips',
#   'Homestyle Ranch',
#   'Grade A Large White Eggs',
#   'American Cheese Slices 12 Count',
#   'French Vanilla Sugar Free Liquid Coffee Creamer',
#   'Chicken Parmesan',
#   'Original Flavor Crispy Corn Snacks',
#   'Cheese Pizza Snacks'],
#  ['Whole Organic Omega 3 Milk',
#   'Marinara Sauce',
#   'Chunky Peanut Butter High Protein Bar',
#   'Asian Salad Kit',
#   'Vanilla Soy Milk',
#   'Roasted & Salted Shelled Pistachios',
#   'With Bleach Cleanser',
#   'Laxative Powder Solution',
#   ' Unflavored',
#   'Frozen Limeade Concentrate',
#   'Original New Orleans Style Dirty Rice Mix',
#   'Cage Free Brown Eggs-Large',
#   ' Grade A',
#   'Reclosable Sandwich Bags Double Zipper'],
#  ['Fresh Cauliflower', 'Roasted Turkey Breast'],
#  ['Cream Cheese',
#   'Pure & Natural Sour Cream',
#   'Unsalted Pure Irish Butter',
#   'Colombian Peaks Whole Bean Coffee',
#   'Heavy Whipping Cream',
#   'Choice Cuts Seafood Selections Wet Cat Food',
#   'Original Hot Sauce',
#   'Triscuit Brown Rice & Wheat Sea Salt & Black Pepper Crackers',
#   'Organic Promise Berry Fruitful Cereal',
#   'Sparkling Water Berry',
#   'Pure Sparkling Water',
#   'Otria Spinach Artichoke Greek Yogurt Veggie Dip',
#   'Classico Traditional Pizza Sauce',
#   'Light Multi-Grain English Muffins',
#   '6 Cheese Italian Shredded Cheese'],
#  ['Baby Cucumbers',
#   'Rainbow Bell Peppers',
#   'Red Seedless Grapes',
#   'Fresh Asparagus'],
#  ['Extra Virgin Olive Oil',
#   'Tomato Sauce',
#   'Pizza Dough',
#   'Organic Premium Tomato Paste',
#   'Organic Tomato Sauce No Salt Added',
#   'Red Onion',
#   'Shredded Mozzarella',
#   'Pitted Castelvetrano Green Olives',
#   '6 OZ LA PANZANELLA CROSTINI ORIGINAL CRACKERS'],
#  ['Organic Egg Whites',
#   'Broccoli Florets',
#   'Berry Medley',
#   'Organic Fuji Apple',
#   'Organic Blackberries',
#   'Spinach',
#   'Organic Mini Peeled Carrots',
#   'Light Wisconsin String Cheese',
#   'Low Fat Cottage Cheese',
#   'Shelled Soybeans Edamame',
#   'Cauliflower Florets',
#   'Total 0% Nonfat Plain Greek Yogurt',
#   'Lime Diet Coke',
#   'Asparagus Tips',
#   'Quick & Easy Fresh Green Beans',
#   'Mini Peppers'],
#  ['Pure Cane Cubes Sugar',
#   'High-Traffic Foam Large Area Carpet Cleaner',
#   'Original Baked Snack Crackers',
#   'All Purpose Cleaner',
#   'Original Style Yoghurt Plain'],
#  ['Carrots', 'Organic Sliced Bella Mushrooms'],
#  ['Sparkling Water Grapefruit',
#   'Organic Gala Apples',
#   'Organic Blackberries',
#   'Brussels Sprouts',
#   'Organic Whole String Cheese',
#   'Organic Broccoli',
#   'Vegan Smooth Chocolate Nutritional Shake',
#   'Green Machine Juice Smoothie',
#   'Blackberry Yogurt',
#   'The Ultimate Beefless Burger',
#   "Lightly Seasoned Chick'n Scallopini",
#   'Natural Spring Water',
#   'Apple Cinnamon Instant Oatmeal',
#   'Organic Butternut Squash',
#   'Light and Lean Quinoa Black Beans with Butternut Squash and Chard',
#   'Butternut Squash Ravioli',
#   'Organic Cut Green Beans',
#   'Rotini'],
#  ['Organic Red Radish',
#   ' Bunch',
#   'Kale Greens',
#   '1 Apple + 1 Pear Fruit Bar',
#   'Gluten Free Quiche & Pie Crusts',
#   'White Horseradish',
#   'Broccoli Rabe',
#   'Sourdough Hard Pretzels Fat Free',
#   'Curly Parsley Bunch'],
#  ['Bag of Organic Bananas',
#   'Organic Half & Half',
#   'Organic Roasted Turkey Breast',
#   'Organic Tomato Basil Pasta Sauce',
#   'Organic Extra Large Grade AA Brown Eggs',
#   'Organic Milk',
#   'Organic Peeled Whole Baby Carrots',
#   'Frozen Organic Wild Blueberries',
#   'Organic Whole String Cheese',
#   'Shredded Mozzarella',
#   'Organic California Style Sprouted Bread',
#   'Original Hummus',
#   'Thin & Light Tortilla Chips',
#   'Kids Sensible Foods Broccoli Littles',
#   'Organic Snack Mix Bunnies Snack Mix',
#   ' Organic',
#   'Organic Small Bunch Celery',
#   'Medium Cheddar Cheese Block',
#   "Organic Bernie's Farm Macaroni & Cheese",
#   'Organic Orzo',
#   'Organic Pinto Beans',
#   'Organic Garbanzo Beans No Salt Added',
#   'Maple Quinoa Cluster With Chia Seeds',
#   'Gluten Free Blueberry Waffles',
#   'Organic Whole Wheat Pie 9\\" Shells 2 ct',
#   'The \\"World\'s Best\\" Veggie Burger',
#   'Organic Roasted Sliced Chicken Breast'],
#  ['Organic Hass Avocado',
#   'Boneless Skinless Chicken Breasts',
#   'Vanilla Whey Protein Powder',
#   'Whole Milk Plain Yogurt',
#   'Low Fat Plain Yogurt',
#   'Apple Blueberry Granola'],
#  ['Strawberries',
#   'Blueberries',
#   'Chili With Beans',
#   'Natural Bliss Cinnamon Cream Coffee Creamer',
#   'Star Wars Italian Sweet Creme Creamer',
#   'Iced Oatmeal Cookie Kid Z Bar',
#   'Scoops! Tortilla Chips',
#   'Original Restaurant Style Tortilla Chips',
#   'Honey Wheat Bread',
#   'Natural Classic Pork Breakfast Sausage',
#   '100 Calorie  Per Bag Popcorn',
#   '7 Grain Waffles'],
#  ['Bag of Organic Bananas',
#   'Lemonade',
#   'Organic Baby Carrots',
#   'Red Peppers',
#   'Organic Beef Uncured Hot Dogs',
#   'Uncured Italian Dry Salami',
#   'Lacinato Kale Og',
#   'Organic Penne Rigate',
#   'Organic White Basmati Rice',
#   'Organic Dill'],
#  ['Bag of Organic Bananas',
#   'Organic Whole Milk',
#   'Organic Tomato Cluster',
#   'Coconut Water',
#   'Tilapia Filet',
#   'Organic Strawberry Smoothie',
#   'Baby Seedless Cucumbers',
#   'Power-C Dragonfruit Vitamin Water Drink',
#   'Cookies',
#   ' Chocolate Chip Walnut',
#   '85% Lean Ground Beef',
#   'Organic Super Fruit Punch Juice Drink',
#   'Small Dog Biscuits',
#   'Organic Bunny Fruit Snacks Berry Patch',
#   'Pomelo Grapefruit & Aloe Appeal',
#   'Juice',
#   ' Watermelon + Peach',
#   ' Comfort',
#   'Organic Bunch Arugula',
#   '100% Guava Juice',
#   'Pyramid Black Tea Bags'],
#  ['Banana',
#   'Organic Vidalia Onion',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Organic Tomato Sauce',
#   'Lime Sparkling Water',
#   'Hommus Artichoke Kalamata',
#   'Sea Salt Lentil Chips',
#   'Three Cheese Pizza Shell',
#   'Wild Skipjack Light Tuna',
#   'Unsweetened Cashew Milk',
#   'Radish',
#   'Nonfat Icelandic Style Strawberry Yogurt',
#   'Garlic',
#   'Unsweetened Coconut Milk Beverage'],
#  ['Organic Red Radish',
#   ' Bunch',
#   'Organic Cilantro',
#   'Total Greek Strained Yogurt',
#   'Organic Yellow Onion',
#   'Organic Grape Tomatoes',
#   'Organic Lemon',
#   'Organic Garlic',
#   'Organic Dill',
#   'Organic Italian Parsley Bunch',
#   'Organic Zucchini',
#   'Yellow Potato',
#   'Organic Kale',
#   'I Heart Baby Kale',
#   'Organic Saffron',
#   'Organic Garbanzo Beans',
#   'High Heat Canola Spray Oil',
#   'Parchment Baking Paper',
#   'Pita Bread'],
#  ['Original Pure Creamy Almond Milk',
#   'Hummus',
#   ' Hope',
#   ' Original Recipe',
#   'Sprouted Grain Low Sodium Bread',
#   'Ezekiel 4:9 Sprouted Whole Grain Cereal Almond',
#   'Peanut Butter Creamy With Salt',
#   'Premium Organic Strawberry Spread',
#   'Organic Orange Mango Juice',
#   'Unsweetened Vanilla Almond Milk',
#   'Seitan wheat Strips',
#   'Chorizo Seitan',
#   'Vegan Chao Creamy Original Cheese Slices'],
#  ['Organic Garnet Sweet Potato (Yam)', 'Original Enriched Rice Drink'],
#  ['Original Potato Chips',
#   'Organic Peeled Whole Baby Carrots',
#   'Total 0% Nonfat Plain Greek Yogurt',
#   'Vitamin D Organic Whole Milk',
#   'All Natural Marinara Sauce',
#   'Eggo Homestyle Waffles',
#   'Extra Sharp Cheddar Cheese',
#   'Everything Deli Style Pretzel Crisps Crackers',
#   'Total 2% All Natural Plain Greek Yogurt',
#   'Plain Mini Bagels',
#   'Organic Sweet Peas',
#   'Mini Seedless Cucumbers',
#   'Vanilla Milk Chocolate Almond Ice Cream Bars',
#   'Roasted Sesame Seaweed Snacks',
#   'Fruit Roll-Ups Strawberry Sensation Fruit Flavored Snacks',
#   'All Natural Virgin Lemonade',
#   'Vanilla Milk Chocolate Ice Cream Bars'],
#  ['Organic Baby Spinach',
#   'Sea Salt & Vinegar Potato Chips',
#   'Boomchickapop Sea Salt Popcorn',
#   'Jalapeno Potato Chips',
#   'Lightly Salted Baked Snap Pea Crisps',
#   'Organic Half Baby Spinach & Half Baby Arugula',
#   'Oven Baked Cheddar & Sour Cream Potato Crisps',
#   'Original Whole Grain Chips',
#   'Kosher Dill Halves Pickles',
#   'Sour Cream and Onion Potato Chips'],
#  ['Organic Avocado',
#   'Roasted & Salted Almonds',
#   'Organic Grade A Free Range Large Brown Eggs',
#   'Organic Cream Cheese Bar'],
#  ['Organic Yellow Onion',
#   'Lemon Cayenne Agave Cold Pressed Juice Beverage',
#   'Bright Beet Juice Smoothie',
#   'Organic Cinnamon Apple Sauce',
#   'No Pulp Calcium & Vitamin D Pure Premium 100% Pure Orange Juice',
#   'Baby Back Pork Ribs'],
#  ['Organic Baby Spinach',
#   'Organic Yellow Onion',
#   'Organic Frozen Peas',
#   'Organic Russet Potato',
#   'Grated Parmesan',
#   'Passion Orange Guava Juice'],
#  ['Sparkling Mineral Water',
#   'Vegetable Classics Minestrone Soup',
#   'Frozen Organic Peach Slices',
#   'Kids Organic Chocolate Chip ZBars',
#   'Black Beans',
#   'Ginger Beer',
#   'Organic Large Grade AA Brown Eggs',
#   'Baked Rice and Corn Puffs',
#   ' Aged White Cheddar',
#   'Tamari Brown Rice Crackers'],
#  ['2% Reduced Fat Milk',
#   'English Breakfast Tea Bags',
#   'Lemon-Lime Fridge Pack Soda',
#   'Coke Classic',
#   'Chocolate Chip Granola',
#   'Natural Pure Sparkling Water',
#   "Crunchy Oats 'n Honey Granola",
#   'Chunky Chocolate Chip Cookies',
#   'Lemon Sparkling Water',
#   'Lactose Free 2% Milk',
#   'Whole Vitamin D Milk',
#   'White Giant Paper Towel Rolls',
#   'Organic Green Tea',
#   'Earl Grey  Black Tea Blend',
#   'Fridge Pack Cola'],
#  ['Fat Free Milk',
#   'Extra Sharp Cheddar Cheese Block',
#   "Chocolate Peanut Butter Builder's Bar",
#   'Slim Can Pink Grapefruit Natural Mineral Water',
#   'Red Hot Original Cayenne Pepper Sauce',
#   'Original Ranch Salad Dressing & Seasoning Mix',
#   'Anti Dandruff 2 in 1 Shampoo'],
#  ['Unsweetened Almondmilk',
#   'Banana',
#   'Yellow Onions',
#   'Honeycrisp Apple',
#   'Organic Red Onion',
#   'Large Lemon',
#   '100 Calorie  Per Bag Popcorn',
#   'Whole Grain White Corn Salted Tortilla Chips',
#   'Golden Sweet Potato',
#   'Organic Honey',
#   'Super Spinach! Baby Spinach',
#   ' Baby Bok Choy',
#   ' Sweet Baby Kale',
#   'Ready Wipe Flushable Wipes',
#   'Broccoli Florets Steamers',
#   'Sharp Cheddar Cheese Shredded',
#   'Spreadable Butter with Canola Oil',
#   'Salted Sweet Cream Butter',
#   'Classic Wheat Bread',
#   'Deli Fresh Shaved Smoked Turkey Breast',
#   'Deli Fresh Honey Ham',
#   ' 97% Fat Free',
#   ' Gluten Free',
#   'Simple Favorites Lasagna with Meat Sauce',
#   'Swedish Meatballs',
#   'Spaghetti with Meatballs',
#   'Classic Macaroni & Beef in tomato sauce. Classic Macaroni & Beef',
#   'Lemon-Lime Soda',
#   'Diet Root Beer'],
#  ['Carrots',
#   'Sea Salt Made With Organic Grain Rice Chips',
#   'Organic Unsalted Butter',
#   'Organic Lactose Free 1% Lowfat Milk',
#   'Organic Lactose Free Whole Milk',
#   'Low Fat Cottage Cheese',
#   'Organic Large Grade A Brown Eggs',
#   'Vanilla Skyr Nonfat Yogurt',
#   'Cheddar Bunnies Snack Crackers',
#   'Broccoli Crown',
#   'Supergreens!',
#   'Tuna Salad',
#   'Gluten Free 7 Grain Bread',
#   'Organic Gluten Free & Wheat Free Pumpkin Spice Waffles'],
#  ['Original Hot Sauce',
#   'Extra Fancy Unsalted Mixed Nuts',
#   'Mixed Fruit Fruit Snacks'],
#  ['Spring Water',
#   'Raspberries',
#   'Strawberries',
#   'Blackberries',
#   'Red Seedless Grapes',
#   'Mixed Fruit Fruit Snacks',
#   'Shredded Mexican Blend Cheese',
#   'Apples',
#   "Crunchy Oats 'n Honey Granola Bars",
#   'Cinnamon Brown Sugar Breakfast Biscuits',
#   'Trail Mix',
#   'Cheez-It Baked Snack Crackers',
#   'Oranges'],
#  ['Carrots',
#   'Vanilla Almond Breeze Almond Milk',
#   'Yellow Onions',
#   'Green Bell Pepper',
#   'Fresh Ginger Root',
#   'Red Peppers',
#   'Organic Skim Milk',
#   'Sesame Seed',
#   'Light Brown Sugar',
#   'Sweet Red Chili Dipping & All-Purpose Sauce',
#   'Organic Cinnamon Crunch Cereal',
#   'Crunchy Peanut Butter'],
#  ['Organic Baby Spinach',
#   'Organic Hass Avocado',
#   'Organic Unsweetened Almond Milk',
#   'Mango Chunks',
#   'Organic Large Green Asparagus',
#   'Cage Free Large White Eggs',
#   'Organic Red Lentils',
#   'Organic Coconut Milk',
#   'Goat Milk',
#   'Sweet Onion',
#   'Organic Yukon Select Fries',
#   'Avocado Oil',
#   ' Refined',
#   'Simply White Natural Clean Mint Fluoride Toothpaste',
#   'Crackers Harvest Whole Wheat'],
#  ['Garlic Alfredo Sauce', 'Classic Hummus', 'Pita Crisps Simply Naked'],
#  ['Tesora Medium Roast',
#   'Dark Chocolate Nuts & Sea Salt Bars',
#   'Organic Raisin Bran Cereal'],
#  ['Peaches', 'Granulated Sugar', 'Canola Oil', 'Organic Sweet Cherries'],
#  ['Bag of Organic Bananas',
#   'Clementines',
#   'Dried Mango',
#   'Mango Peach Salsa',
#   'Pure Clover Honey'],
#  ['Organic Gluten Free & Wheat Free Pumpkin Spice Waffles',
#   'Peach Pear Flavored Sparkling Water',
#   'Kiwi Sandia Sparkling Water',
#   'Brown Rice Snaps Black Sesame',
#   'Macadamias',
#   ' Maui Onion',
#   ' Sweet',
#   'Peanut Butter Cookie',
#   'Apple Pie Fruit & Nut Food Bar',
#   'Butter 2.0 Featuring Virgin Coconut Oil',
#   'Organic Smoked Turkey Breast'],
#  ['Original Hummus',
#   'White Cheddar Macaroni & Cheese Cups',
#   'Cold Pressed Watermelon & Lemon Juice Blend',
#   'Paleo Blueberry Muffin'],
#  ['Organic Hazelnut Spread',
#   'Organic Heavy Whipping Cream',
#   'Organic Butternut Squash',
#   'Organic Red Bell Pepper',
#   'Premium Fish Sauce',
#   'Premium Pure Cane Granulated Sugar'],
#  ['Chocolate Chip Cookie Dough Ice Cream',
#   'Classic White Bread',
#   'Mild Salsa',
#   'Natural Premium Coconut Water',
#   'Organic Free Range Chicken Broth'],
#  ['Parsley',
#   ' Italian (Flat)',
#   ' New England Grown',
#   'Organic Blueberries',
#   'Organic Mint',
#   'Organic Garbanzo Beans',
#   'Matcha Powder',
#   'Shelled Edamame',
#   'Organic Basil'],
#  ['Organic Raspberries',
#   'Organic Hass Avocado',
#   'Banana',
#   'Cucumber Kirby',
#   'Plain Greek Yogurt',
#   'Cold-Pressed Organic Grapefruit',
#   'Organic Traditional Plain Kefir',
#   'Plain Cultured Goat Milk Kefir'],
#  ['Organic Cucumber',
#   'Organic Baby Arugula',
#   'Mild Cheddar Cheese Sticks',
#   'Italian Sparkling Mineral Water'],
#  ['Organic Strawberries',
#   'Organic Red Delicious Apple',
#   'Pomegranate',
#   'Yogurt',
#   ' Nonfat',
#   ' Organic',
#   ' Plain',
#   'Chocolate Malt'],
#  ['Chocolate Chip Cookie Dough Ice Cream',
#   'Oven Roasted Turkey Breast',
#   'Dulce de Leche Caramel Ice Cream',
#   'Classic Soda Mini Bottles',
#   'Vanilla Ice Cream',
#   'Caramel Cone Ice Cream',
#   'Rum Raisin Ice Cream',
#   'Diet Coke Soda',
#   'Coffee Ice Cream'],
#  ['Organic Avocado',
#   'Seven Grain Crispy Tenders',
#   'Fresh Cauliflower',
#   'Organic Garbanzo Beans No Salt Added',
#   'Organic Zucchini',
#   'Dairy Free Cultured Plain Coconut Milk',
#   'Whole Almonds',
#   'Jumbo Veggie Protein Smart Dogs Links',
#   'Wheat Hot Dog Rolls',
#   'Dairy Free Mozarella Style Shreds',
#   'Basil'],
#  ['Bag of Organic Bananas',
#   'Organic Raspberries',
#   'Seedless Red Grapes',
#   'Organic Cucumber',
#   'Large Alfresco Eggs',
#   'Limes',
#   'Organic Baby Arugula',
#   'Original Hummus',
#   'Grated Parmesan',
#   'Sharp Cheddar Cheese',
#   'Organic Granny Smith Apple',
#   'Whole Grain Organic Waffles',
#   ' Totally Original',
#   'Apple and Carrot Stage 2 Baby Food',
#   'Organic Milk Chocolate Peanut Butter Cups',
#   'Original Puffins Cereal',
#   'Organic Fuji Red Apple Chips',
#   'Baby Food Stage 2 Pumpkin Banana',
#   'Fresh Whole Milk Ricotta',
#   'Organic Soft Wheat Bread'],
#  ['Michigan Organic Kale',
#   'Large Lemon',
#   'Cage Free Brown Eggs-Large',
#   ' Grade A',
#   'Romaine Hearts',
#   'Traditional Favorites Italian Sausage with Peppers & Onions Pasta Sauce',
#   'Healthy Pop Butter Microwave Popcorn'],
#  ['Large Lemon',
#   'Organic Raw Sharp Cheddar Cheese',
#   'Tilapia Filet',
#   'Organic Lacinato (Dinosaur) Kale',
#   'Natural Free & Clear Dish Liquid',
#   'Free & Clear Ultra Powdered Laundry Detergent',
#   'Organic Quinoa Dark Chocolate Bar',
#   'Pizza',
#   ' Rice Crust',
#   ' Cheese',
#   'Triple Blade Cartridges'],
#  ['Assorted Bites',
#   'Salad Hearts of Romaine',
#   'Creamy Caesar Dressing',
#   'Shredded Parmesan Cheese',
#   'Gourmet Cut Caesar Croutons',
# ...
#   'Organic Yellow Onion',
#   'Organic Grape Tomatoes',
#   'Organic Lemon',
#   'Organic Cucumber',
#   'Organic Garlic',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Organic Iceberg Lettuce',
#   'Organic Broccoli',
#   'Organic Butternut Squash',
#   'Organic Small Bunch Celery',
#   'Organic Zucchini',
#   'Premium Organic Strawberry Spread',
#   'Organic Grade A Free Range Large Brown Eggs',
#   'Organic Granny Smith Apple',
#   'Organic Lacinato (Dinosaur) Kale',
#   'Peanut & Gluten Free Smooth Almond Butter',
#   'Organic Romaine Lettuce',
#   'Organic Red Cabbage',
#   'Almond Milk Blueberry Yogurt',
#   'Organic Creamy Peanut Butter',
#   'Organic Carrot Bunch',
#   'Taco Seasoning',
#   'Almond Milk Ricotta',
#   'Almond Milk Strawberry Yogurt',
#   'Gluten Free Rice Millet Bread',
#   'Gluten Free Brown Rice Bread',
#   'Rocky Mountain Sourdough Bread',
#   'Dark Chocolate Frozen Dessert bars'],
#  ['Organic Raspberries',
#   'Organic Black Beans',
#   'Lemon Hummus',
#   'Organic Gala Apples',
#   'Ancient Grain Blueberry Hemp Granola',
#   'Organic Pinto Beans',
#   'Pumpkin Fig Ancient Grain Granola',
#   'Strawberry Rhubarb Yogurt',
#   'Organic Sea Salt Dark Chocolate',
#   'Ancient Grain Granola Cranberry Pecan',
#   'Mixed Berries Whole Milk Icelandic Style Skyr Yogurt'],
#  ['Organic Baby Spinach',
#   'Organic Red Radish',
#   ' Bunch',
#   'Organic Grape Tomatoes',
#   'Organic Cucumber',
#   'Frozen Organic Wild Blueberries',
#   'Organic Whole Grassmilk Milk',
#   "Mac n' Cheese Puffs"],
#  ['Organic Egg Whites',
#   'Organic Hass Avocado',
#   'Organic Whole Milk',
#   'Organic Unsweetened Almond Milk',
#   'Organic Whole Strawberries',
#   'Organic Celery',
#   'Walnut Halves & Pieces',
#   'Cane Sugar',
#   'Ravioli',
#   ' Spinach & Cheese',
#   'Lowfat Small Curd Cottage Cheese',
#   'Organic Romaine Hearts',
#   'Organic Chopped Garlic',
#   'Ripe Large Pitted Olives'],
#  ['Yellow Onions',
#   'Large Lemon',
#   'Roma Tomato',
#   'Unsweetened Original Almond Breeze Almond Milk',
#   'Zero Rise Orange',
#   'Protein Plus Farfalle Multigrain Pasta',
#   'Cinnamon Raisin Swirl Pre-Sliced Bagels',
#   'Philadelphia Cream Cheese',
#   'Tomato and Basil Pasta Sauce',
#   'Select-A-Size White Paper Towels',
#   'Chicken Broccoli Supreme'],
#  ['Carrots',
#   'Bag of Organic Bananas',
#   'Organic Avocado',
#   'Organic No Salt Added Diced Tomatoes',
#   'Organic Grape Tomatoes',
#   'Organic Garlic',
#   'Organic Whole Wheat Bread',
#   'Organic Spring Mix Salad',
#   'Boneless Skinless Chicken Breast',
#   'Organic Baby Arugula',
#   'Sour Cream',
#   'Original Hummus',
#   'Organic Small Bunch Celery',
#   'Organic Dill',
#   'Organic Leek',
#   'Organic Reduced Fat 2% Milk',
#   'Half & Half',
#   'Low Fat 1% Milk',
#   'Organic Hothouse Cucumbers',
#   'Original Tofurky Deli Slices',
#   'Citrus Mandarins Organic',
#   'Organic Vegetable Broth',
#   'Cream Top Smooth & Creamy Vanilla Yogurt',
#   'Cream Top Blueberry Yogurt',
#   'Mild Sliced Cheddar Cheese'],
#  ['Homemade Hot Arrabbiata Fra Diavolo Sauce', 'Smoked Wild Sockeye Salmon'],
#  ['Organic Baby Spinach',
#   '2% Reduced Fat Milk',
#   'Organic Half & Half',
#   'Watermelon Chunks',
#   'Spaghetti',
#   'Pad Thai',
#   'Pizza Roasted Vegetable No Cheese',
#   'Blue Cheese Crumbles',
#   'Apple Sauce',
#   'Tommy/Kent/Keitt/Haden Mango',
#   'Stuffed Grape Leaves',
#   'Organic All Stars Pasta In Tomato & Cheese Sauce',
#   'Organic Chicken Noodles Soup',
#   'Light & Lean Spaghetti Italiano with Meatless Meatballs',
#   'Farmstand Flaxbread Breakfast Sandwich',
#   'Egg & Smoked Gouda Multi-Grain Flatbread Breakfast Sandwich',
#   'Sensitive Facial Cleansing Towelettes',
#   'Oh My Yog! Pacific Coast Strawberry Trilayer Yogurt',
#   'Light & Lean Roasted Polenta With Swiss Chard',
#   'Organic Soups Alphabet Fat Free',
#   'Tomato Basil Bisque RTS Organic Soup',
#   'Organic Cheesy Ravioli',
#   "Organic Bernie O's",
#   'Organic Mushroom Chef S Sampler'],
#  ['Banana',
#   'Organic Whole Milk',
#   'Organic Kiwi',
#   'Organic Vanilla Almond Milk',
#   'Organic Whole String Cheese',
#   'Whole Milk Plain Yogurt'],
#  ['Green Beans',
#   'Organic Strawberries',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Red Onion',
#   'Romaine Hearts'],
#  ['Organic Lemon',
#   'Tahitian Vanilla Gelato',
#   'Jamon Serrano Dry Cured Ham',
#   'Garlic & Fine Herbs Gournay Cheese'],
#  ['Organic Hass Avocado',
#   'Banana',
#   'Organic Strawberries',
#   'Organic Sour Cream',
#   'Smartwater',
#   'Organic Fuji Apple',
#   'Shredded Parmesan',
#   'Authentic French Brioche',
#   'Organic Vanilla Almond Milk',
#   'Organic Whole String Cheese',
#   'Russet Potato',
#   'Mild Cheddar Cheese Sticks',
#   'Organic Kale Greens',
#   'Uncured Hickory Smoked Sunday Bacon',
#   'Organic Mexican Blend Finely Shredded Cheese',
#   'Shredded 3 Cheese Blend',
#   'Basil Dish Soap',
#   'Jalapeno Hummus',
#   'Apple Sauce',
#   'Organic Chives',
#   'Shishito Peppers',
#   'Gluten Free Mini Pretzels',
#   'Tuscan Vodka Fresh Pasta Sauce',
#   'White Cheddar Jalapeno Gourmet Popcorn',
#   'Cheddar Snack Crackers Cheddar Bunnies',
#   'Organic Parsley'],
#  ['Organic Fat Free Milk',
#   'White Cheddar Semisoft Cheese',
#   'Organic 2% Reduced Fat Milk',
#   'Plain Greek Yogurt',
#   'Orange Sparkling Water',
#   'Peach on the Bottom Nonfat Greek Yogurt',
#   'Non Fat Black Cherry on the Bottom Greek Yogurt',
#   'Strawberry on the Bottom Nonfat Greek Yogurt',
#   'Blueberry on the Bottom Nonfat Greek Yogurt',
#   'Pomegranate on the Bottom Non-Fat Greek Yogurt',
#   'Raspberry on the Bottom Nonfat Greek Yogurt',
#   'Low-Fat Mango on the Bottom Greek Yogurt',
#   'Non-Fat Blackberry on the Bottom Greek Yogurt',
#   'Paper Napkins',
#   'Dove Dark Chocolate Snowflake Promises',
#   'Mini Babybel Mozzarella Cheese',
#   '0% Milkfat Greek Yogurt Honey',
#   'Coconut Blended Greek Yogurt',
#   'Coffee Blended Low-Fat Greek Yogurt'],
#  ['Extra Virgin Olive Oil',
#   'Organic Half & Half',
#   'Red Delicious Apple',
#   'Grated Parmesan Cheese',
#   'Dressing',
#   ' Jersey Sweet Onion',
#   ' Calorie Free',
#   'Unrefined Virgin Coconut Oil',
#   'Organic Whole Wheat Penne Rigate',
#   'Diced Tomatoes',
#   'Chopped Spinach',
#   'Organic Macaroni & Cheese',
#   'Roasted Garlic Pasta Sauce',
#   'Bombay Curry Veggie Burgers',
#   'Organic Pizza Snack Mix Crackers'],
#  ['Ginger Ale',
#   'Small Cherry Pie',
#   'Sharp Cheddar Deli Sliced Cheese',
#   'Root Beer Soda'],
#  ['Banana',
#   'Organic Unsalted Butter',
#   'Large Lemon',
#   'Organic Yellow Onion',
#   'Organic Shredded Mild Cheddar',
#   'Organic Whole Grain Wheat English Muffins',
#   'Baby Seedless Cucumbers',
#   'Organic Whole String Cheese',
#   'Organic Creamy Peanut Butter',
#   'Aged White Cheddar Baked Rice & Corn Puffs Gluten Free Lunch Packs',
#   'American Cheese slices',
#   'Kitchen Scrubber Sponge',
#   'Organic Freeze Dried Bananas',
#   'Crispy Wheat',
#   ' Crackers',
#   'Tomatoes',
#   ' Whole Peeled',
#   'Frozen Organic Mango Chunks',
#   'Tommy/Kent/Keitt/Haden Mango',
#   'Organic Freeze Dried Strawberries',
#   'Organic Fancy Shredded Mozzarella Cheese',
#   'Premium Mango Fruit Snack Pack',
#   "Sheep's Milk Halloumi Cheese"],
#  ['Organic Baby Spinach',
#   'Organic Hass Avocado',
#   'Watermelon Chunks',
#   'Organic Tomato Cluster',
#   '100% Whole Wheat Bread',
#   'Organic Strawberry Smoothie',
#   'Organic Peeled Whole Baby Carrots',
#   'Whole Milk Plain Yogurt',
#   'Cream Cheese Spread',
#   'Organic Whole Milk French Vanilla Yogurt',
#   'No Pulp Orange Juice'],
#  ['Unsweetened Almondmilk',
#   'Banana',
#   'Steamfresh Premium Selects Frozen Whole Green Beans',
#   'Seven Grain Crispy Tenders',
#   'Dha Omega 3 Vitamin D Milk',
#   'Unsweetened Vanilla Almond Milk',
#   'Eggo Homestyle Waffles',
#   'Lemon Sparkling Water',
#   'Orange Sparkling Water',
#   'Passionfruit Sparkling Water',
#   'Carb Balance Flour Tortillas',
#   'Cheerios Cereal',
#   'Organic Cheesy Ravioli',
#   'Canned Diet',
#   'Bathroom Tissue Double Rolls',
#   'Cool Touch Coconut Oil & Aloe Facial Tissues',
#   'Mexican Finely Shredded Cheese',
#   'Pro-Health For Me Cross Action Toothbrush',
#   'Wholesome Breakfast Apple Raisin Baby Food',
#   'Thick Medium Cheddar Slices',
#   'Golden Fishless Filet',
#   'Santa Cruz OG Blackberry Pom Fruit Spread',
#   'Santa Cruz OG Apricot Fruit Spread',
#   'Max Force Laundry Stain Remover',
#   'Turkey & Sweet Potato Dog Treats',
#   'Soft & Chewy Strawberry Newtons',
#   'Natural Lemon Flavored Sparkling Water',
#   'Berry Bunnies Cereal Organic'],
#  ['Lemonade',
#   'Sour Cream & Onion Flavored Potato Chips',
#   'Aluminum Foil',
#   'Mandarin Orange Segments in Light Syrup',
#   'Pineapple Cottage Doubles',
#   'Berry Punch Flavored Fruit Drink',
#   'Foam Plates',
#   'Fettuccini with Chicken Broccoli',
#   'Grilled Chicken Alfredo Bake Frozen Dinner',
#   'Fruit Flavored Snacks Assorted Flavors'],
#  ['Corn Tortillas', 'Organic Guacamole'],
#  ['Organic Baby Spinach',
#   'Green Beans',
#   'Organic Mini Homestyle Waffles',
#   'Organic Garnet Sweet Potato (Yam)',
#   'Organic Cucumber',
#   'Tilapia Filet',
#   'Organic Reduced Fat Milk',
#   'Organic Yokids Lemonade/Blueberry Variety Pack Yogurt Squeezers Tubes',
#   'Organic Romaine',
#   'Unsweetened Original Almond Breeze Almond Milk',
#   'Original Enriched Rice Drink',
#   'Organic Cream of Mushroom Condensed Soup',
#   'Lime Italian Sparkling Mineral Water',
#   'Breaded Fish Sticks',
#   'Organic White English Muffins',
#   'Extra Wide Egg Noodles'],
#  ['Banana',
#   'Go Lean Cereal',
#   'Organic Go Go Apple Peach Applesauce',
#   'Organic Apple Banana GoGo Squeez',
#   'Cheddar Snack Crackers Cheddar Bunnies',
#   'Organic Sweet Potato Puree'],
#  ['Unsweetened Almondmilk',
#   'Bag of Organic Bananas',
#   'Organic Half & Half',
#   'Sparkling Water Grapefruit',
#   'Sparkling Water Berry',
#   'Pure Sparkling Water',
#   'Power-C Dragonfruit Vitamin Water Drink',
#   'Peach Pear Flavored Sparkling Water',
#   'Original Puffins Cereal',
#   'Small Hass Avocado',
#   'Sparkling Lemon Water',
#   'Milk',
#   ' Reduced Fat',
#   ' 2% Milkfat',
#   'Organic Creamy Peanut Butter',
#   'Strawberry Rhubarb Yogurt',
#   'Mixed Berries Whole Milk Icelandic Style Skyr Yogurt',
#   'Strained Whole-Milk Yogurt Blueberry',
#   'Vanilla Skyr Style Yogurt',
#   'Unsweetened Green Tea',
#   'vitaminwater® XXX Acai Blueberry Pomegranate',
#   'Crunchy Almond Butter',
#   'Pretzel Sticks',
#   ' Thin',
#   'Dairy Free Coconut Milk Raspberry Yogurt Alternative'],
#  ['Michigan Organic Kale',
#   'Banana',
#   'Large Lemon',
#   'Strawberries',
#   'Sliced Peaches',
#   'Natural Tomato Paste',
#   'Chicken Broth',
#   'Lentils',
#   'Bunched Carrots'],
#  ['Honeycrisp Apple',
#   'Large Lemon',
#   'Seedless Red Grapes',
#   'Original Pure Creamy Almond Milk',
#   'Granny Smith Apples',
#   'Whole Milk',
#   'Bartlett Pears',
#   'Mountain Chai Black & Spices Concentrate'],
#  ['Tomato Ketchup',
#   'Ginger Root Beer',
#   ' Naturally Flavored Zero Calorie Soda',
#   ' Caffeine Free',
#   'Guacamole',
#   'Organic Restaurant Style  Sea Salt & Lime Tortilla Chips',
#   'Diet Mountain Zevia Soda',
#   'Glutenfree Brownie Mix'],
#  ['Clementines',
#   'Banana',
#   'Honeycrisp Apple',
#   'Vanilla Soy Milk',
#   'Vanilla Almond Breeze',
#   'Pure Peppermint Herbal Tea',
#   'Herbal Tea Bags Organic Turmeric With Meadowsweet & Ginger 16 Ct',
#   'Organic Green Tea Lemongrass'],
#  ['Organic Baby Spinach Salad',
#   'Blueberries',
#   'Icelandic Style Skyr Blueberry Non-fat Yogurt',
#   'Unsweetened Original Almond Breeze Almond Milk',
#   'Original Hummus',
#   'Peanut Butter Creamy With Salt',
#   'Whole Strawberries',
#   'Mixed Berries Whole Milk Icelandic Style Skyr Yogurt',
#   'Cage Free Large Brown Eggs',
#   'House Napa Cabbage',
#   'White Peach'],
#  ['Chunky Salsa Medium',
#   'Soda',
#   'Salsa Con Queso Medium Dip',
#   'With Bleach Cleanser',
#   'Scoops! Tortilla Chips',
#   'Ranch Dressing',
#   'Extra Crunchy Peanut Butter',
#   'Blueberry Lemonade',
#   'Sausage',
#   ' Egg',
#   ' & Cheese Croissant',
#   'No Beans Chili',
#   'Rigatoni with Chicken & Pesto',
#   'Extra Fresh Body Wash with Pump',
#   'Mini & Meatballs in Tomato Sauce Beef Ravioli',
#   'Flour corn tortillas filled with chicken and vegetables over a bed of rice topped with a Real cheese sauce Chicken Enchiladas',
#   'Diet Caffeine Free Soda'],
#  ['Organic Baby Spinach',
#   'Organic Whole Wheat Bread',
#   'Milk',
#   ' Organic',
#   ' Vitamin D',
#   'Oats & Honey Gluten Free Granola',
#   'Quick Cooking Rolled Oats Irish Oatmeal',
#   'Organic Soba'],
#  ['Organic Baby Spinach',
#   'Bag of Organic Bananas',
#   'Organic Raspberries',
#   'Organic Cucumber',
#   'Organic Roma Tomato',
#   'Tortilla Chips with Salt',
#   'Colby Cheese Sticks',
#   'Mini Blueberry Muffins',
#   'Kefir Cultured Milk Smoothie',
#   ' Whole Milk',
#   ' Sublime Slime Lime'],
#  ['Banana',
#   'Organic Avocado',
#   'Organic Lemon',
#   'Organic Spring Mix Salad',
#   'Tilapia Filet',
#   'Organic Roma Tomato',
#   'Unsweetened Original Almond Breeze Almond Milk',
#   'Italian Sparkling Mineral Water',
#   'Barista Blend Pure Almond Milk',
#   'Organic Black Lentils',
#   'Lavender Dish Soap',
#   'Organic Golden Delicious Apple'],
#  ['Organic Hass Avocado',
#   'Unsweetened Vanilla Almond Milk',
#   'Red Raspberries',
#   'Organic Thyme',
#   'Non Fat Acai & Mixed Berries Yogurt',
#   'Classic French Demi-Glace',
#   'Non Fat Raspberry Yogurt'],
#  ['Clementines',
#   'Organic Strawberries',
#   'Apricots',
#   'Premium Grapefruit Large',
#   'Granny Smith Apples',
#   'Seedless Cucumbers',
#   'Hass Avocado Variety'],
#  ['Boneless Skinless Chicken Breasts',
#   'Organic Tomato Cluster',
#   'Limes',
#   'Bunched Cilantro',
#   'Thick & Chunky Salsa',
#   'Colby Jack Cheese',
#   'Total 0% Nonfat Greek Yogurt',
#   'Sliced Black Olives',
#   'Spicy Organic Microgreens'],
#  ['Banana',
#   'Seedless Red Grapes',
#   'Mango Yoghurt',
#   'Marinara Sauce',
#   'Cherry Garcia Ice Cream',
#   'Apple Honeycrisp Organic',
#   'Smoked Turkey Breast Slices',
#   'Coconut Yoghurt',
#   'Half & Half',
#   'Organic Raw Kombucha Gingerade',
#   'Seedless Small Watermelon',
#   'Baby Arugula',
#   'Cold Brew Coffee Double Espresso with Almond Milk',
#   'Hearty Nine Grain Bread',
#   'Tart Cherry Yoghurt',
#   'Vanilla Yogurt',
#   "Organic Cookies 'n Cream Ice Cream"],
#  ['Organic Bread with 21 Whole Grains',
#   'Organic Sour Cream',
#   'Organic Lemon',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Frozen Organic Wild Blueberries',
#   'Organic Small Bunch Celery',
#   'Organic Zucchini',
#   'Organic Coconut Milk',
#   'Coconut Milk Yogurt Alternative Natural Flavor'],
#  ['Banana',
#   'Organic Strawberries',
#   'Organic Low Sodium Vegetable Broth',
#   'Sprouted Whole Wheat Bread',
#   'Sourdough Bread',
#   'Colby Cheese Sticks',
#   'Organic Whipped Naturally Buttery Spread',
#   'Organic Vanilla Whole Milk Yogurt',
#   'Organic Infant Formula With Iron'],
#  ['Banana',
#   'Organic Bosc Pear',
#   "Organic D'Anjou Pears",
#   'Organic Large Extra Fancy Fuji Apple',
#   'Apple Honeycrisp Organic',
#   'Medium Navel Orange',
#   'Persimmon Sharon Fruit Cv'],
#  ['Organic Tomato Cluster',
#   'Uncured Genoa Salami',
#   'Organic Lemon',
#   'Limes',
#   'Jalapeno Peppers',
#   'Red Peppers',
#   'Bunched Cilantro',
#   'Organic Italian Parsley Bunch',
#   'Rosemary Crackers',
#   'Whole Wheat Crackers',
#   'Lavender Floral & Mint Natural Dish Liquid',
#   'Organic Low Fat Cottage Cheese',
#   '100% Grated Parmesan Cheese',
#   'Stuffed Jalapenos With Cream Cheese',
#   'Thirsty Ultra Big Roll towel White Vsa',
#   'Pro-V Daily Moisture Renewal Conditioner',
#   'White Whole Mushrooms',
#   'Medium Cheddar Cheese',
#   'Italian Seasoning',
#   '3D White Mint Toothpaste'],
#  ['Michigan Organic Kale',
#   'Bartlett Pears',
#   'Tortillas',
#   ' Brown Rice',
#   'Organic Gluten Free Crispy Brown Rice Cereal',
#   'Gluten Free Brown Rice Bread',
#   'Sunflower Seed Butter',
#   'Steel Cut Oats with Currants',
#   ' Flax and Chia'],
#  ['Organic Strawberries',
#   'Fresh Ginger Root',
#   'Kale Greens',
#   'Talenti Double Dark Chocolate Gelato',
#   'Seedless Small Watermelon',
#   'Original Whole Fat Lactose Free Milk',
#   'Black Cherry Gelato',
#   'Passion Fruit',
#   '100% Premium Arabica Ground Coffee',
#   'Condensed Milk',
#   ' Sweetened',
#   ' Full Cream'],
#  ['Coconut Water', 'Semi-Sweet Chocolate Morsels'],
#  ['Enchilada with Spanish Rice & Beans Meal',
#   'Icelandic Style Fat Free Plain Yogurt',
#   'Black Bean Tamale Verde',
#   'Indian Paneer Tikka',
#   'Blueberry Pint',
#   'Cheese Enchilada Meal',
#   'Cheese Tamale Verde',
#   'Indian Samosa Wrap',
#   'Indian Mattar Tofu'],
#  ...]

# %%
len(trans_list)
# Out:
# 9428

# %%
rules = apriori(trans_list, min_support=0.01, min_confidence=0.01, min_lift=1.8,
                min_length=2)

Results = list(rules)
Results
# Out:
# Total time required to run apriori algorithm using apyori package:  0.0
# [RelationRecord(items=frozenset({' Bag', 'Clementines'}), support=0.011985574883326262, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bag'}), items_add=frozenset({'Clementines'}), confidence=0.8828125, lift=42.902867268041234), OrderedStatistic(items_base=frozenset({'Clementines'}), items_add=frozenset({' Bag'}), confidence=0.5824742268041236, lift=42.902867268041234)]),
#  RelationRecord(items=frozenset({'Organic Baby Spinach', 'Bag of Organic Bananas'}), support=0.015803988120492152, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bag of Organic Bananas'}), items_add=frozenset({'Organic Baby Spinach'}), confidence=0.13104661389621813, lift=1.8010313058506482), OrderedStatistic(items_base=frozenset({'Organic Baby Spinach'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.21720116618075805, lift=1.8010313058506482)]),
#  RelationRecord(items=frozenset({'Bag of Organic Bananas', 'Organic Hass Avocado'}), support=0.019304200254560883, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bag of Organic Bananas'}), items_add=frozenset({'Organic Hass Avocado'}), confidence=0.1600703605980651, lift=2.4699563988847095), OrderedStatistic(items_base=frozenset({'Organic Hass Avocado'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.2978723404255319, lift=2.4699563988847095)]),
#  RelationRecord(items=frozenset({'Organic Raspberries', 'Bag of Organic Bananas'}), support=0.012940178192617734, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bag of Organic Bananas'}), items_add=frozenset({'Organic Raspberries'}), confidence=0.10729991204925242, lift=2.4916836719220488), OrderedStatistic(items_base=frozenset({'Organic Raspberries'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.3004926108374384, lift=2.4916836719220488)]),
#  RelationRecord(items=frozenset({'Banana', 'Honeycrisp Apple'}), support=0.010182435299109036, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Banana'}), items_add=frozenset({'Honeycrisp Apple'}), confidence=0.06818181818181818, lift=2.5815991237677984), OrderedStatistic(items_base=frozenset({'Honeycrisp Apple'}), items_add=frozenset({'Banana'}), confidence=0.38554216867469876, lift=2.5815991237677984)]),
#  RelationRecord(items=frozenset({'Banana', 'Organic Avocado'}), support=0.015591854051760713, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Banana'}), items_add=frozenset({'Organic Avocado'}), confidence=0.10440340909090909, lift=1.8784643910478833), OrderedStatistic(items_base=frozenset({'Organic Avocado'}), items_add=frozenset({'Banana'}), confidence=0.28053435114503816, lift=1.8784643910478835)]),
#  RelationRecord(items=frozenset({'Banana', 'Organic Fuji Apple'}), support=0.010394569367840474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Banana'}), items_add=frozenset({'Organic Fuji Apple'}), confidence=0.06960227272727272, lift=2.4669557416267938), OrderedStatistic(items_base=frozenset({'Organic Fuji Apple'}), items_add=frozenset({'Banana'}), confidence=0.3684210526315789, lift=2.466955741626794)]),
#  RelationRecord(items=frozenset({'Banana', 'Strawberries'}), support=0.013576580398812049, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Banana'}), items_add=frozenset({'Strawberries'}), confidence=0.09090909090909091, lift=1.9932346723044398), OrderedStatistic(items_base=frozenset({'Strawberries'}), items_add=frozenset({'Banana'}), confidence=0.29767441860465116, lift=1.9932346723044398)]),
#  RelationRecord(items=frozenset({'Organic Baby Spinach', 'Organic Strawberries'}), support=0.012515910055154858, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Organic Baby Spinach'}), items_add=frozenset({'Organic Strawberries'}), confidence=0.17201166180758018, lift=2.1680828175426012), OrderedStatistic(items_base=frozenset({'Organic Strawberries'}), items_add=frozenset({'Organic Baby Spinach'}), confidence=0.15775401069518716, lift=2.1680828175426012)]),
#  RelationRecord(items=frozenset({'Organic Strawberries', 'Organic Hass Avocado'}), support=0.011773440814594823, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Organic Hass Avocado'}), items_add=frozenset({'Organic Strawberries'}), confidence=0.18166939443535188, lift=2.289811565155745), OrderedStatistic(items_base=frozenset({'Organic Strawberries'}), items_add=frozenset({'Organic Hass Avocado'}), confidence=0.14839572192513367, lift=2.289811565155745)]),
#  RelationRecord(items=frozenset({'Organic Strawberries', 'Organic Raspberries'}), support=0.010076368264743318, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Organic Raspberries'}), items_add=frozenset({'Organic Strawberries'}), confidence=0.23399014778325122, lift=2.9492768894391608), OrderedStatistic(items_base=frozenset({'Organic Strawberries'}), items_add=frozenset({'Organic Raspberries'}), confidence=0.12700534759358287, lift=2.9492768894391608)])]

# %%
df_results = pd.DataFrame(Results)
df_results.head()
# Out:
#                                             items   support  \
# 0                             ( Bag, Clementines)  0.011986
# 1  (Organic Baby Spinach, Bag of Organic Bananas)  0.015804
# 2  (Bag of Organic Bananas, Organic Hass Avocado)  0.019304
# 3   (Organic Raspberries, Bag of Organic Bananas)  0.012940
# 4                      (Banana, Honeycrisp Apple)  0.010182
#
#                                   ordered_statistics
# 0  [(( Bag), (Clementines), 0.8828125, 42.9028672...
# 1  [((Bag of Organic Bananas), (Organic Baby Spin...
# 2  [((Bag of Organic Bananas), (Organic Hass Avoc...
# 3  [((Bag of Organic Bananas), (Organic Raspberri...
# 4  [((Banana), (Honeycrisp Apple), 0.068181818181...

# %%
df_results["ordered_statistics"][1]
# Out:
# [OrderedStatistic(items_base=frozenset({'Bag of Organic Bananas'}), items_add=frozenset({'Organic Baby Spinach'}), confidence=0.13104661389621813, lift=1.8010313058506482),
#  OrderedStatistic(items_base=frozenset({'Organic Baby Spinach'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.21720116618075805, lift=1.8010313058506482)]

# %%
support = df_results["support"]

# %%
#all four empty list which will contain lhs, rhs, confidance and lift respectively.

first_values = []
second_values = []
third_values = []
fourth_value = []

# loop number of rows time and append 1 by 1 value in a separate list.. first and second element was frozenset which need to be converted in list..
for i in range(df_results.shape[0]):
    single_list = df_results['ordered_statistics'][i][0]
    first_values.append(list(single_list[0]))
    second_values.append(list(single_list[1]))
    third_values.append(single_list[2])
    fourth_value.append(single_list[3])

# %%
lhs = pd.DataFrame(first_values)
rhs= pd.DataFrame(second_values)
confidance=pd.DataFrame(third_values,columns=['Confidance'])
lift=pd.DataFrame(fourth_value,columns=['lift'])

# %%
lhs.head()
# Out:
#                         0
# 0                     Bag
# 1  Bag of Organic Bananas
# 2  Bag of Organic Bananas
# 3  Bag of Organic Bananas
# 4                  Banana

# %%
rhs.head()
# Out:
#                       0
# 0           Clementines
# 1  Organic Baby Spinach
# 2  Organic Hass Avocado
# 3   Organic Raspberries
# 4      Honeycrisp Apple

# %%
df_final = pd.concat([lhs,rhs,support,confidance,lift], axis=1)
df_final
# Out:
#                          0                     0   support  Confidance  \
# 0                      Bag           Clementines  0.011986    0.882812
# 1   Bag of Organic Bananas  Organic Baby Spinach  0.015804    0.131047
# 2   Bag of Organic Bananas  Organic Hass Avocado  0.019304    0.160070
# 3   Bag of Organic Bananas   Organic Raspberries  0.012940    0.107300
# 4                   Banana      Honeycrisp Apple  0.010182    0.068182
# 5                   Banana       Organic Avocado  0.015592    0.104403
# 6                   Banana    Organic Fuji Apple  0.010395    0.069602
# 7                   Banana          Strawberries  0.013577    0.090909
# 8     Organic Baby Spinach  Organic Strawberries  0.012516    0.172012
# 9     Organic Hass Avocado  Organic Strawberries  0.011773    0.181669
# 10     Organic Raspberries  Organic Strawberries  0.010076    0.233990
#
#          lift
# 0   42.902867
# 1    1.801031
# 2    2.469956
# 3    2.491684
# 4    2.581599
# 5    1.878464
# 6    2.466956
# 7    1.993235
# 8    2.168083
# 9    2.289812
# 10   2.949277

# %%
df_final.shape
# Out:
# (11, 5)

# %%
df_final.columns = [["antecedents","consequents","support","confidence","lift"]]

# %%
df_final
# Out:
#                antecedents           consequents   support confidence  \
# 0                      Bag           Clementines  0.011986   0.882812
# 1   Bag of Organic Bananas  Organic Baby Spinach  0.015804   0.131047
# 2   Bag of Organic Bananas  Organic Hass Avocado  0.019304   0.160070
# 3   Bag of Organic Bananas   Organic Raspberries  0.012940   0.107300
# 4                   Banana      Honeycrisp Apple  0.010182   0.068182
# 5                   Banana       Organic Avocado  0.015592   0.104403
# 6                   Banana    Organic Fuji Apple  0.010395   0.069602
# 7                   Banana          Strawberries  0.013577   0.090909
# 8     Organic Baby Spinach  Organic Strawberries  0.012516   0.172012
# 9     Organic Hass Avocado  Organic Strawberries  0.011773   0.181669
# 10     Organic Raspberries  Organic Strawberries  0.010076   0.233990
#
#          lift
# 0   42.902867
# 1    1.801031
# 2    2.469956
# 3    2.491684
# 4    2.581599
# 5    1.878464
# 6    2.466956
# 7    1.993235
# 8    2.168083
# 9    2.289812
# 10   2.949277

# %% [markdown]
# # Implementing Apriori algorithm using Mlxtend package

# %%
subset.head(10)
# Out:
#    order_id        product_name
# 0         2  Organic Egg Whites
# 1        26  Organic Egg Whites
# 2       120  Organic Egg Whites
# 3       327  Organic Egg Whites
# 4       390  Organic Egg Whites
# 5       537  Organic Egg Whites
# 6       582  Organic Egg Whites
# 7       608  Organic Egg Whites
# 8       623  Organic Egg Whites
# 9       689  Organic Egg Whites

# %%
data = subset[subset['order_id']<10000]

# %%
te = TransactionEncoder()
te_array = te.fit(trans_list).transform(trans_list)

# %%
df_trans = pd.DataFrame(te_array, columns=te.columns_)
df_trans.head()
# Out:
#             Apricot & Banana Stage 2 Baby Food   & Baby Wipes  \
# 0  False                                 False          False
# 1  False                                 False          False
# 2  False                                 False          False
# 3  False                                 False          False
# 4  False                                 False          False
#
#     & Cheese Biscuit   & Cheese Croissant   & Cheese Sandwiches  \
# 0              False                False                 False
# 1              False                False                 False
# 2              False                False                 False
# 3              False                False                 False
# 4              False                False                 False
#
#     & Cheese Sauce   & Grape Ice Pops   & Peas   & Raisin  ...  \
# 0            False              False    False      False  ...
# 1            False              False    False      False  ...
# 2            False              False    False      False  ...
# 3            False              False    False      False  ...
# 4            False              False    False      False  ...
#
#    of Norwich Original English Mustard Powder Double Superfine  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    smartwater® Electrolyte Enhanced Water  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    vitaminwater® XXX Acai Blueberry Pomegranate  w/Banana Pulp Free Juice  \
# 0                                         False                     False
# 1                                         False                     False
# 2                                         False                     False
# 3                                         False                     False
# 4                                         False                     False
#
#    with Crispy Almonds Cereal  with Olive Oil Mayonnaise  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    with Olive Oil Mayonnaise Dressing  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#    with Xylitol Cinnamon 18 Sticks Sugar Free Gum  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    with Xylitol Minty Sweet Twist 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#     Lightly Seasoned with Rosemary and Roasted Garlic Family Size Herb Chicken Tortellini
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 16548 columns]

# %%
freq_itemsets = frequent_patterns.apriori(df_trans,min_support=0.01,use_colnames=True)
freq_itemsets
# Out:
#       support                                      itemsets
# 0    0.013577                                        ( Bag)
# 1    0.015062                                      ( Bunch)
# 2    0.021744                                    ( Organic)
# 3    0.011986                                 ( Strawberry)
# 4    0.012304                      (100% Raw Coconut Water)
# ..        ...                                           ...
# 116  0.018562                (Banana, Organic Strawberries)
# 117  0.013577                        (Banana, Strawberries)
# 118  0.012516  (Organic Baby Spinach, Organic Strawberries)
# 119  0.011773  (Organic Strawberries, Organic Hass Avocado)
# 120  0.010076   (Organic Strawberries, Organic Raspberries)
#
# [121 rows x 2 columns]

# %%
rules = frequent_patterns.association_rules(freq_itemsets,metric='lift',min_threshold=1)
rules.sort_values(by='confidence',ascending=False)
# Out:
#                  antecedents               consequents  antecedent support  \
# 0                     ( Bag)             (Clementines)            0.013577
# 1              (Clementines)                    ( Bag)            0.020577
# 11        (Honeycrisp Apple)                  (Banana)            0.026411
# 17      (Organic Fuji Apple)                  (Banana)            0.028214
# 6      (Organic Raspberries)  (Bag of Organic Bananas)            0.043063
# 5     (Organic Hass Avocado)  (Bag of Organic Bananas)            0.064807
# 23            (Strawberries)                  (Banana)            0.045609
# 13         (Organic Avocado)                  (Banana)            0.055579
# 29     (Organic Raspberries)    (Organic Strawberries)            0.043063
# 21    (Organic Strawberries)                  (Banana)            0.079338
# 2     (Organic Baby Spinach)  (Bag of Organic Bananas)            0.072762
# 8     (Organic Strawberries)  (Bag of Organic Bananas)            0.079338
# 15    (Organic Baby Spinach)                  (Banana)            0.072762
# 27    (Organic Hass Avocado)    (Organic Strawberries)            0.064807
# 19    (Organic Hass Avocado)                  (Banana)            0.064807
# 24    (Organic Baby Spinach)    (Organic Strawberries)            0.072762
# 4   (Bag of Organic Bananas)    (Organic Hass Avocado)            0.120598
# 25    (Organic Strawberries)    (Organic Baby Spinach)            0.079338
# 26    (Organic Strawberries)    (Organic Hass Avocado)            0.079338
# 9   (Bag of Organic Bananas)    (Organic Strawberries)            0.120598
# 3   (Bag of Organic Bananas)    (Organic Baby Spinach)            0.120598
# 28    (Organic Strawberries)     (Organic Raspberries)            0.079338
# 20                  (Banana)    (Organic Strawberries)            0.149342
# 7   (Bag of Organic Bananas)     (Organic Raspberries)            0.120598
# 12                  (Banana)         (Organic Avocado)            0.149342
# 14                  (Banana)    (Organic Baby Spinach)            0.149342
# 22                  (Banana)            (Strawberries)            0.149342
# 18                  (Banana)    (Organic Hass Avocado)            0.149342
# 16                  (Banana)      (Organic Fuji Apple)            0.149342
# 10                  (Banana)        (Honeycrisp Apple)            0.149342
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.020577  0.011986    0.882812  42.902867  0.011706    8.357743
# 1             0.013577  0.011986    0.582474  42.902867  0.011706    2.362545
# 11            0.149342  0.010182    0.385542   2.581599  0.006238    1.384404
# 17            0.149342  0.010395    0.368421   2.466956  0.006181    1.346875
# 6             0.120598  0.012940    0.300493   2.491684  0.007747    1.257173
# 5             0.120598  0.019304    0.297872   2.469956  0.011489    1.252481
# 23            0.149342  0.013577    0.297674   1.993235  0.006765    1.211201
# 13            0.149342  0.015592    0.280534   1.878464  0.007292    1.182346
# 29            0.079338  0.010076    0.233990   2.949277  0.006660    1.201893
# 21            0.149342  0.018562    0.233957   1.566583  0.006713    1.110457
# 2             0.120598  0.015804    0.217201   1.801031  0.007029    1.123407
# 8             0.120598  0.017183    0.216578   1.795860  0.007615    1.122513
# 15            0.149342  0.014955    0.205539   1.376296  0.004089    1.070736
# 27            0.079338  0.011773    0.181669   2.289812  0.006632    1.125049
# 19            0.149342  0.011243    0.173486   1.161667  0.001565    1.029211
# 24            0.079338  0.012516    0.172012   2.168083  0.006743    1.111926
# 4             0.064807  0.019304    0.160070   2.469956  0.011489    1.113418
# 25            0.072762  0.012516    0.157754   2.168083  0.006743    1.100911
# 26            0.064807  0.011773    0.148396   2.289812  0.006632    1.098154
# 9             0.079338  0.017183    0.142480   1.795860  0.007615    1.073633
# 3             0.072762  0.015804    0.131047   1.801031  0.007029    1.067075
# 28            0.043063  0.010076    0.127005   2.949277  0.006660    1.096154
# 20            0.079338  0.018562    0.124290   1.566583  0.006713    1.051332
# 7             0.043063  0.012940    0.107300   2.491684  0.007747    1.071958
# 12            0.055579  0.015592    0.104403   1.878464  0.007292    1.054516
# 14            0.072762  0.014955    0.100142   1.376296  0.004089    1.030427
# 22            0.045609  0.013577    0.090909   1.993235  0.006765    1.049830
# 18            0.064807  0.011243    0.075284   1.161667  0.001565    1.011330
# 16            0.028214  0.010395    0.069602   2.466956  0.006181    1.044485
# 10            0.026411  0.010182    0.068182   2.581599  0.006238    1.044828

# %%
rules[(rules['confidence']>0.16) & (rules['lift']>2)]
# Out:
#                  antecedents               consequents  antecedent support  \
# 0                     ( Bag)             (Clementines)            0.013577
# 1              (Clementines)                    ( Bag)            0.020577
# 4   (Bag of Organic Bananas)    (Organic Hass Avocado)            0.120598
# 5     (Organic Hass Avocado)  (Bag of Organic Bananas)            0.064807
# 6      (Organic Raspberries)  (Bag of Organic Bananas)            0.043063
# 11        (Honeycrisp Apple)                  (Banana)            0.026411
# 17      (Organic Fuji Apple)                  (Banana)            0.028214
# 24    (Organic Baby Spinach)    (Organic Strawberries)            0.072762
# 27    (Organic Hass Avocado)    (Organic Strawberries)            0.064807
# 29     (Organic Raspberries)    (Organic Strawberries)            0.043063
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.020577  0.011986    0.882812  42.902867  0.011706    8.357743
# 1             0.013577  0.011986    0.582474  42.902867  0.011706    2.362545
# 4             0.064807  0.019304    0.160070   2.469956  0.011489    1.113418
# 5             0.120598  0.019304    0.297872   2.469956  0.011489    1.252481
# 6             0.120598  0.012940    0.300493   2.491684  0.007747    1.257173
# 11            0.149342  0.010182    0.385542   2.581599  0.006238    1.384404
# 17            0.149342  0.010395    0.368421   2.466956  0.006181    1.346875
# 24            0.079338  0.012516    0.172012   2.168083  0.006743    1.111926
# 27            0.079338  0.011773    0.181669   2.289812  0.006632    1.125049
# 29            0.079338  0.010076    0.233990   2.949277  0.006660    1.201893

# %%
rules.antecedents.values
# Out:
# array([frozenset({' Bag'}), frozenset({'Clementines'}),
#        frozenset({'Organic Baby Spinach'}),
#        frozenset({'Bag of Organic Bananas'}),
#        frozenset({'Bag of Organic Bananas'}),
#        frozenset({'Organic Hass Avocado'}),
#        frozenset({'Organic Raspberries'}),
#        frozenset({'Bag of Organic Bananas'}),
#        frozenset({'Organic Strawberries'}),
#        frozenset({'Bag of Organic Bananas'}), frozenset({'Banana'}),
#        frozenset({'Honeycrisp Apple'}), frozenset({'Banana'}),
#        frozenset({'Organic Avocado'}), frozenset({'Banana'}),
#        frozenset({'Organic Baby Spinach'}), frozenset({'Banana'}),
#        frozenset({'Organic Fuji Apple'}), frozenset({'Banana'}),
#        frozenset({'Organic Hass Avocado'}), frozenset({'Banana'}),
#        frozenset({'Organic Strawberries'}), frozenset({'Banana'}),
#        frozenset({'Strawberries'}), frozenset({'Organic Baby Spinach'}),
#        frozenset({'Organic Strawberries'}),
#        frozenset({'Organic Strawberries'}),
#        frozenset({'Organic Hass Avocado'}),
#        frozenset({'Organic Strawberries'}),
#        frozenset({'Organic Raspberries'})], dtype=object)

# %%
rules[rules["antecedents"] == frozenset({'Bag of Organic Bananas'})]
# Out:
#                 antecedents             consequents  antecedent support  \
# 3  (Bag of Organic Bananas)  (Organic Baby Spinach)            0.120598
# 4  (Bag of Organic Bananas)  (Organic Hass Avocado)            0.120598
# 7  (Bag of Organic Bananas)   (Organic Raspberries)            0.120598
# 9  (Bag of Organic Bananas)  (Organic Strawberries)            0.120598
#
#    consequent support   support  confidence      lift  leverage  conviction
# 3            0.072762  0.015804    0.131047  1.801031  0.007029    1.067075
# 4            0.064807  0.019304    0.160070  2.469956  0.011489    1.113418
# 7            0.043063  0.012940    0.107300  2.491684  0.007747    1.071958
# 9            0.079338  0.017183    0.142480  1.795860  0.007615    1.073633
